# %%
import torch
import torch.nn as nn
from Memory.dataset import *
from Utils.utils import *
from torch.utils.data import Dataset,DataLoader
from sklearn.metrics import precision_score,recall_score

# %%
from torch.utils.tensorboard import SummaryWriter

# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter('TensorBoard/TrainAgent_RNN_OldData_5layer')

# %%
class Feeder(Dataset):
    def __init__(self,data_dir):
        self.data_dir = data_dir
        self.paths = os.listdir(data_dir)
        data = list()
        for file_dir in self.paths:
            f = open(data_dir + file_dir)
            try:
                js = json.load(f)['logs']
                data.extend(js)
            except json.JSONDecodeError:
                f.close()
                continue
            f.close()
        
#         self.data = list()
#         for idx,i in enumerate(data):
#             if decode_state_old_test(i,isImitation=True)[-1]  in ran:
#                 ip = list()
#                 try:
#                     for idx_2 in range(10,0,-1):
#                         ip.append(data[idx-idx_2])
#                 except IndexError:
#                     continue
#                 ip.append(i)
                
        self.data = data
             

    def __len__(self):
        return len(self.data) - 7

    def __getitem__(self, index):
        index = index + 6
        reward = Reward(self.data[index]['player_board_card_info'],self.data[index]['opponent_board_card_info'],self.data[index]['player_hand_card_id'],self.data[index]['opponent_life'],self.data[index]['player_life'],self.data[index]['player_gold'])
        return_reward = [max(reward[:56])] +[max(reward[56:105])] + [max(reward[105:114])]  + [max(reward[114:177])] + [max(reward[177:289])] + [reward[289]]          
        return_data = list()
        for i in self.data[index-4:index+1]:
            return_data.append(decode_state_old_test(i,isImitation=True)[:-1])
        return np.array(return_data),np.array(return_reward,dtype=np.float)

# %%
dataset = Feeder('Log/ImitationLog/Train/')

# %%
dataloader = DataLoader(dataset,batch_size=256,num_workers = 20)

# %%
def accuracy(pred, label):
    pred = torch.argmax(pred, dim=1).long()
#     print(pred)
    label = torch.argmax(label,dim=1).long()
    acc = torch.mean((pred == label).float())
    pred = pred.detach().cpu().numpy()
    label = label.detach().cpu().numpy()
    p = precision_score(label, pred,average='micro')
    r = recall_score(label, pred,average='micro')
    return p,r,acc 

class AverageMeter(object):

    def __init__(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class RNN(nn.Module):
    def __init__(self,input_size,output_size,hidden_size):
        super(RNN, self).__init__()

        self.dense1 = nn.Linear(input_size,1024)
        self.dense2 = nn.Linear(1024,512)

        self.rnn = nn.LSTM(
            input_size=512,
            hidden_size=hidden_size,
            num_layers=5,
            batch_first=True)
        self.dense3 = nn.Linear(hidden_size,output_size)

    def forward(self, x):
        dense1 = self.dense1(x.float())
        dense2 = self.dense2(dense1)
        out, (h_n, h_c) = self.rnn(dense2, None)
        out = self.dense3(out)
        return out[:, -1, :]

# %%
model = RNN(516,6,512).to(torch.device('cuda:2'))

# %%
crit = nn.BCEWithLogitsLoss().to(torch.device('cuda:2'))
losses = 0.0
accs  = 0.0
precisions  = AverageMeter()
recalls  = AverageMeter()

opt = torch.optim.SGD(model.parameters(), 0.01, 
                          momentum=0.9, 
                          weight_decay=1e-4) 
# checkpoint = torch.load('Models/1stImitationAgent_NewData_Oldecode.ckpt')
# model.load_state_dict(checkpoint)
for epoch in range(20):
    for i, (data,reward) in enumerate(dataloader):
        data_,reward_ = map(lambda x:x.to(torch.device('cuda:2')),(data,reward))

        pred = model.forward(data_.float())
#         y_onehot = label.detach().numpy()
#         y_onehot = (np.arange(56) == y_onehot[:,None]).astype(np.float32)
#         y_onehot = torch.from_numpy(y_onehot).to(torch.device('cuda:1'))
        loss = crit(pred,torch.nn.functional.softmax(reward_))
        p,r, acc = accuracy(pred, torch.nn.functional.softmax(reward_))

        opt.zero_grad()
        loss.backward()
        opt.step()

#         losses.update(loss.item(),530)
#         accs.update(acc.item(),530)
        losses += loss.item()
        accs += acc.item()
        precisions.update(p, 530)
        recalls.update(r,530)

        if i % 5 == 0:
            print('Epoch:[{0}][{1}/{2}]\t'
#                   'Loss {losses.val:.3f} ({losses.avg:.3f})\t'
#                   'Accuracy {accs.val:.3f} ({accs.avg:.3f})\t'
                  'Loss {losses:.3f} \t'
                  'Accuracy {accs:.3f}\t'
                  'Precison {precisions.val:.3f} ({precisions.avg:.3f})\t'
                  'Recall {recalls.val:.3f} ({recalls.avg:.3f})'.format(
                        epoch,i,len(dataloader) ,losses=loss, accs=acc, 
                        precisions=precisions, recalls=recalls))
        if i % 10 == 0:
            torch.save(model.state_dict(), 'Models/ImitationAgent_RNN_OldData_5Layer.ckpt')
            # ...log the running loss
            writer.add_scalar('training loss',
                            losses / 10,
                            epoch * len(dataloader) + i)

            # ...log a Matplotlib Figure showing the model's predictions on a
            # random mini-batch
            writer.add_scalar('accuracy',
                            accs / 10,
                            global_step=epoch * len(dataloader) + i)
            losses = 0.0
            accs = 0.0
    #         print('Epoch:[{0}][{1}/{2}]\t'
    #               'Loss {losses:.3f} \t'
    #               'Accuracy {accs:.3f}\t'
    #               'Precison {precisions:.3f}\t'
    #               'Recall {recalls:.3f}'.format(
    #                     epoch, losses=loss, accs=acc, 
    #                     precisions=
# Out:
# /home/kietcdx/myenv/lib/python3.6/site-packages/ipykernel_launcher.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /home/kietcdx/myenv/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch:[0][0/1224]	Loss 0.698 	Accuracy 0.352	Precison 0.352 (0.352)	Recall 0.352 (0.352)
# Epoch:[0][5/1224]	Loss 0.694 	Accuracy 0.191	Precison 0.191 (0.288)	Recall 0.191 (0.288)
# Epoch:[0][10/1224]	Loss 0.686 	Accuracy 0.613	Precison 0.613 (0.294)	Recall 0.613 (0.294)
# Epoch:[0][15/1224]	Loss 0.676 	Accuracy 0.281	Precison 0.281 (0.269)	Recall 0.281 (0.269)
# Epoch:[0][20/1224]	Loss 0.666 	Accuracy 0.316	Precison 0.316 (0.254)	Recall 0.316 (0.254)
# Epoch:[0][25/1224]	Loss 0.652 	Accuracy 0.707	Precison 0.707 (0.307)	Recall 0.707 (0.307)
# Epoch:[0][30/1224]	Loss 0.647 	Accuracy 0.000	Precison 0.000 (0.330)	Recall 0.000 (0.330)
# Epoch:[0][35/1224]	Loss 0.628 	Accuracy 0.781	Precison 0.781 (0.349)	Recall 0.781 (0.349)
# Epoch:[0][40/1224]	Loss 0.618 	Accuracy 0.547	Precison 0.547 (0.405)	Recall 0.547 (0.405)
# Epoch:[0][45/1224]	Loss 0.609 	Accuracy 0.398	Precison 0.398 (0.413)	Recall 0.398 (0.413)
# Epoch:[0][50/1224]	Loss 0.598 	Accuracy 0.344	Precison 0.344 (0.390)	Recall 0.344 (0.390)
# Epoch:[0][55/1224]	Loss 0.587 	Accuracy 0.465	Precison 0.465 (0.396)	Recall 0.465 (0.396)
# Epoch:[0][60/1224]	Loss 0.569 	Accuracy 0.645	Precison 0.645 (0.408)	Recall 0.645 (0.408)
# Epoch:[0][65/1224]	Loss 0.558 	Accuracy 0.965	Precison 0.965 (0.427)	Recall 0.965 (0.427)
# Epoch:[0][70/1224]	Loss 0.560 	Accuracy 0.391	Precison 0.391 (0.431)	Recall 0.391 (0.431)
# Epoch:[0][75/1224]	Loss 0.550 	Accuracy 0.344	Precison 0.344 (0.430)	Recall 0.344 (0.430)
# Epoch:[0][80/1224]	Loss 0.548 	Accuracy 0.336	Precison 0.336 (0.421)	Recall 0.336 (0.421)
# Epoch:[0][85/1224]	Loss 0.538 	Accuracy 0.324	Precison 0.324 (0.418)	Recall 0.324 (0.418)
# Epoch:[0][90/1224]	Loss 0.506 	Accuracy 0.645	Precison 0.645 (0.421)	Recall 0.645 (0.421)
# Epoch:[0][95/1224]	Loss 0.513 	Accuracy 0.355	Precison 0.355 (0.432)	Recall 0.355 (0.432)
# Epoch:[0][100/1224]	Loss 0.499 	Accuracy 0.973	Precison 0.973 (0.438)	Recall 0.973 (0.438)
# Epoch:[0][105/1224]	Loss 0.507 	Accuracy 0.379	Precison 0.379 (0.432)	Recall 0.379 (0.432)
# Epoch:[0][110/1224]	Loss 0.519 	Accuracy 0.238	Precison 0.238 (0.427)	Recall 0.238 (0.427)
# Epoch:[0][115/1224]	Loss 0.518 	Accuracy 1.000	Precison 1.000 (0.437)	Recall 1.000 (0.437)
# Epoch:[0][120/1224]	Loss 0.462 	Accuracy 0.695	Precison 0.695 (0.441)	Recall 0.695 (0.441)
# Epoch:[0][125/1224]	Loss 0.463 	Accuracy 0.609	Precison 0.609 (0.438)	Recall 0.609 (0.438)
# Epoch:[0][130/1224]	Loss 0.440 	Accuracy 0.738	Precison 0.738 (0.449)	Recall 0.738 (0.449)
# Epoch:[0][135/1224]	Loss 0.453 	Accuracy 0.500	Precison 0.500 (0.452)	Recall 0.500 (0.452)
# Epoch:[0][140/1224]	Loss 0.505 	Accuracy 0.000	Precison 0.000 (0.450)	Recall 0.000 (0.450)
# Epoch:[0][145/1224]	Loss 0.397 	Accuracy 0.973	Precison 0.973 (0.465)	Recall 0.973 (0.465)
# Epoch:[0][150/1224]	Loss 0.490 	Accuracy 0.086	Precison 0.086 (0.458)	Recall 0.086 (0.458)
# Epoch:[0][155/1224]	Loss 0.498 	Accuracy 0.000	Precison 0.000 (0.455)	Recall 0.000 (0.455)
# Epoch:[0][160/1224]	Loss 0.436 	Accuracy 0.605	Precison 0.605 (0.458)	Recall 0.605 (0.458)
# Epoch:[0][165/1224]	Loss 0.395 	Accuracy 0.750	Precison 0.750 (0.457)	Recall 0.750 (0.457)
# Epoch:[0][170/1224]	Loss 0.387 	Accuracy 0.691	Precison 0.691 (0.453)	Recall 0.691 (0.453)
# Epoch:[0][175/1224]	Loss 0.441 	Accuracy 1.000	Precison 1.000 (0.450)	Recall 1.000 (0.450)
# Epoch:[0][180/1224]	Loss 0.488 	Accuracy 0.000	Precison 0.000 (0.438)	Recall 0.000 (0.438)
# Epoch:[0][185/1224]	Loss 0.450 	Accuracy 0.016	Precison 0.016 (0.426)	Recall 0.016 (0.426)
# Epoch:[0][190/1224]	Loss 0.428 	Accuracy 0.078	Precison 0.078 (0.425)	Recall 0.078 (0.425)
# Epoch:[0][195/1224]	Loss 0.458 	Accuracy 0.168	Precison 0.168 (0.423)	Recall 0.168 (0.423)
# Epoch:[0][200/1224]	Loss 0.398 	Accuracy 0.590	Precison 0.590 (0.427)	Recall 0.590 (0.427)
# Epoch:[0][205/1224]	Loss 0.410 	Accuracy 0.855	Precison 0.855 (0.433)	Recall 0.855 (0.433)
# Epoch:[0][210/1224]	Loss 0.340 	Accuracy 1.000	Precison 1.000 (0.432)	Recall 1.000 (0.432)
# Epoch:[0][215/1224]	Loss 0.479 	Accuracy 0.000	Precison 0.000 (0.432)	Recall 0.000 (0.432)
# Epoch:[0][220/1224]	Loss 0.412 	Accuracy 0.000	Precison 0.000 (0.422)	Recall 0.000 (0.422)
# Epoch:[0][225/1224]	Loss 0.398 	Accuracy 0.023	Precison 0.023 (0.413)	Recall 0.023 (0.413)
# Epoch:[0][230/1224]	Loss 0.441 	Accuracy 0.520	Precison 0.520 (0.410)	Recall 0.520 (0.410)
# Epoch:[0][235/1224]	Loss 0.430 	Accuracy 0.219	Precison 0.219 (0.408)	Recall 0.219 (0.408)
# Epoch:[0][240/1224]	Loss 0.340 	Accuracy 1.000	Precison 1.000 (0.414)	Recall 1.000 (0.414)
# Epoch:[0][245/1224]	Loss 0.476 	Accuracy 0.848	Precison 0.848 (0.420)	Recall 0.848 (0.420)
# Epoch:[0][250/1224]	Loss 0.427 	Accuracy 0.105	Precison 0.105 (0.422)	Recall 0.105 (0.422)
# Epoch:[0][255/1224]	Loss 0.445 	Accuracy 0.246	Precison 0.246 (0.424)	Recall 0.246 (0.424)
# Epoch:[0][260/1224]	Loss 0.394 	Accuracy 0.285	Precison 0.285 (0.422)	Recall 0.285 (0.422)
# Epoch:[0][265/1224]	Loss 0.354 	Accuracy 0.660	Precison 0.660 (0.422)	Recall 0.660 (0.422)
# Epoch:[0][270/1224]	Loss 0.349 	Accuracy 0.660	Precison 0.660 (0.423)	Recall 0.660 (0.423)
# Epoch:[0][275/1224]	Loss 0.377 	Accuracy 0.465	Precison 0.465 (0.423)	Recall 0.465 (0.423)
# Epoch:[0][280/1224]	Loss 0.417 	Accuracy 0.449	Precison 0.449 (0.421)	Recall 0.449 (0.421)
# Epoch:[0][285/1224]	Loss 0.361 	Accuracy 0.645	Precison 0.645 (0.423)	Recall 0.645 (0.423)
# Epoch:[0][290/1224]	Loss 0.396 	Accuracy 0.219	Precison 0.219 (0.421)	Recall 0.219 (0.421)
# Epoch:[0][295/1224]	Loss 0.387 	Accuracy 0.387	Precison 0.387 (0.419)	Recall 0.387 (0.419)
# Epoch:[0][300/1224]	Loss 0.437 	Accuracy 0.379	Precison 0.379 (0.424)	Recall 0.379 (0.424)
# Epoch:[0][305/1224]	Loss 0.387 	Accuracy 0.785	Precison 0.785 (0.425)	Recall 0.785 (0.425)
# Epoch:[0][310/1224]	Loss 0.353 	Accuracy 0.961	Precison 0.961 (0.431)	Recall 0.961 (0.431)
# Epoch:[0][315/1224]	Loss 0.368 	Accuracy 0.605	Precison 0.605 (0.434)	Recall 0.605 (0.434)
# Epoch:[0][320/1224]	Loss 0.398 	Accuracy 0.449	Precison 0.449 (0.438)	Recall 0.449 (0.438)
# Epoch:[0][325/1224]	Loss 0.396 	Accuracy 0.410	Precison 0.410 (0.437)	Recall 0.410 (0.437)
# Epoch:[0][330/1224]	Loss 0.273 	Accuracy 1.000	Precison 1.000 (0.437)	Recall 1.000 (0.437)
# Epoch:[0][335/1224]	Loss 0.375 	Accuracy 0.285	Precison 0.285 (0.435)	Recall 0.285 (0.435)
# Epoch:[0][340/1224]	Loss 0.481 	Accuracy 0.070	Precison 0.070 (0.433)	Recall 0.070 (0.433)
# Epoch:[0][345/1224]	Loss 0.360 	Accuracy 0.398	Precison 0.398 (0.432)	Recall 0.398 (0.432)
# Epoch:[0][350/1224]	Loss 0.359 	Accuracy 0.566	Precison 0.566 (0.436)	Recall 0.566 (0.436)
# Epoch:[0][355/1224]	Loss 0.371 	Accuracy 0.484	Precison 0.484 (0.436)	Recall 0.484 (0.436)
# Epoch:[0][360/1224]	Loss 0.297 	Accuracy 0.930	Precison 0.930 (0.440)	Recall 0.930 (0.440)
# Epoch:[0][365/1224]	Loss 0.509 	Accuracy 0.000	Precison 0.000 (0.434)	Recall 0.000 (0.434)
# Epoch:[0][370/1224]	Loss 0.397 	Accuracy 0.387	Precison 0.387 (0.434)	Recall 0.387 (0.434)
# Epoch:[0][375/1224]	Loss 0.385 	Accuracy 0.406	Precison 0.406 (0.435)	Recall 0.406 (0.435)
# Epoch:[0][380/1224]	Loss 0.392 	Accuracy 0.359	Precison 0.359 (0.433)	Recall 0.359 (0.433)
# Epoch:[0][385/1224]	Loss 0.353 	Accuracy 0.598	Precison 0.598 (0.432)	Recall 0.598 (0.432)
# Epoch:[0][390/1224]	Loss 0.408 	Accuracy 0.406	Precison 0.406 (0.431)	Recall 0.406 (0.431)
# Epoch:[0][395/1224]	Loss 0.329 	Accuracy 0.578	Precison 0.578 (0.429)	Recall 0.578 (0.429)
# Epoch:[0][400/1224]	Loss 0.368 	Accuracy 0.551	Precison 0.551 (0.430)	Recall 0.551 (0.430)
# Epoch:[0][405/1224]	Loss 0.369 	Accuracy 0.418	Precison 0.418 (0.431)	Recall 0.418 (0.431)
# Epoch:[0][410/1224]	Loss 0.448 	Accuracy 0.000	Precison 0.000 (0.431)	Recall 0.000 (0.431)
# Epoch:[0][415/1224]	Loss 0.475 	Accuracy 0.309	Precison 0.309 (0.430)	Recall 0.309 (0.430)
# Epoch:[0][420/1224]	Loss 0.488 	Accuracy 0.062	Precison 0.062 (0.429)	Recall 0.062 (0.429)
# Epoch:[0][425/1224]	Loss 0.292 	Accuracy 0.773	Precison 0.773 (0.429)	Recall 0.773 (0.429)
# Epoch:[0][430/1224]	Loss 0.469 	Accuracy 0.203	Precison 0.203 (0.426)	Recall 0.203 (0.426)
# Epoch:[0][435/1224]	Loss 0.387 	Accuracy 0.000	Precison 0.000 (0.423)	Recall 0.000 (0.423)
# Epoch:[0][440/1224]	Loss 0.452 	Accuracy 0.312	Precison 0.312 (0.426)	Recall 0.312 (0.426)
# Epoch:[0][445/1224]	Loss 0.498 	Accuracy 0.000	Precison 0.000 (0.421)	Recall 0.000 (0.421)
# Epoch:[0][450/1224]	Loss 0.473 	Accuracy 0.105	Precison 0.105 (0.422)	Recall 0.105 (0.422)
# Epoch:[0][455/1224]	Loss 0.494 	Accuracy 0.000	Precison 0.000 (0.421)	Recall 0.000 (0.421)
# Epoch:[0][460/1224]	Loss 0.492 	Accuracy 0.000	Precison 0.000 (0.419)	Recall 0.000 (0.419)
# Epoch:[0][465/1224]	Loss 0.346 	Accuracy 0.531	Precison 0.531 (0.420)	Recall 0.531 (0.420)
# Epoch:[0][470/1224]	Loss 0.379 	Accuracy 0.000	Precison 0.000 (0.417)	Recall 0.000 (0.417)
# Epoch:[0][475/1224]	Loss 0.287 	Accuracy 1.000	Precison 1.000 (0.417)	Recall 1.000 (0.417)
# Epoch:[0][480/1224]	Loss 0.387 	Accuracy 0.551	Precison 0.551 (0.419)	Recall 0.551 (0.419)
# Epoch:[0][485/1224]	Loss 0.361 	Accuracy 0.977	Precison 0.977 (0.422)	Recall 0.977 (0.422)
# Epoch:[0][490/1224]	Loss 0.490 	Accuracy 0.012	Precison 0.012 (0.421)	Recall 0.012 (0.421)
# Epoch:[0][495/1224]	Loss 0.354 	Accuracy 1.000	Precison 1.000 (0.426)	Recall 1.000 (0.426)
# Epoch:[0][500/1224]	Loss 0.414 	Accuracy 0.996	Precison 0.996 (0.432)	Recall 0.996 (0.432)
# Epoch:[0][505/1224]	Loss 0.333 	Accuracy 0.914	Precison 0.914 (0.437)	Recall 0.914 (0.437)
# Epoch:[0][510/1224]	Loss 0.415 	Accuracy 0.324	Precison 0.324 (0.438)	Recall 0.324 (0.438)
# Epoch:[0][515/1224]	Loss 0.485 	Accuracy 0.160	Precison 0.160 (0.437)	Recall 0.160 (0.437)
# Epoch:[0][520/1224]	Loss 0.310 	Accuracy 0.777	Precison 0.777 (0.437)	Recall 0.777 (0.437)
# Epoch:[0][525/1224]	Loss 0.422 	Accuracy 0.418	Precison 0.418 (0.437)	Recall 0.418 (0.437)
# Epoch:[0][530/1224]	Loss 0.506 	Accuracy 0.000	Precison 0.000 (0.436)	Recall 0.000 (0.436)
# Epoch:[0][535/1224]	Loss 0.505 	Accuracy 0.000	Precison 0.000 (0.434)	Recall 0.000 (0.434)
# Epoch:[0][540/1224]	Loss 0.426 	Accuracy 0.223	Precison 0.223 (0.433)	Recall 0.223 (0.433)
# Epoch:[0][545/1224]	Loss 0.389 	Accuracy 0.438	Precison 0.438 (0.435)	Recall 0.438 (0.435)
# Epoch:[0][550/1224]	Loss 0.504 	Accuracy 0.000	Precison 0.000 (0.436)	Recall 0.000 (0.436)
# Epoch:[0][555/1224]	Loss 0.483 	Accuracy 0.070	Precison 0.070 (0.433)	Recall 0.070 (0.433)
# Epoch:[0][560/1224]	Loss 0.459 	Accuracy 0.164	Precison 0.164 (0.429)	Recall 0.164 (0.429)
# Epoch:[0][565/1224]	Loss 0.497 	Accuracy 0.000	Precison 0.000 (0.427)	Recall 0.000 (0.427)
# Epoch:[0][570/1224]	Loss 0.492 	Accuracy 0.000	Precison 0.000 (0.423)	Recall 0.000 (0.423)
# Epoch:[0][575/1224]	Loss 0.318 	Accuracy 0.832	Precison 0.832 (0.422)	Recall 0.832 (0.422)
# Epoch:[0][580/1224]	Loss 0.387 	Accuracy 0.438	Precison 0.438 (0.422)	Recall 0.438 (0.422)
# Epoch:[0][585/1224]	Loss 0.326 	Accuracy 0.793	Precison 0.793 (0.424)	Recall 0.793 (0.424)
# Epoch:[0][590/1224]	Loss 0.428 	Accuracy 0.199	Precison 0.199 (0.423)	Recall 0.199 (0.423)
# Epoch:[0][595/1224]	Loss 0.388 	Accuracy 0.328	Precison 0.328 (0.424)	Recall 0.328 (0.424)
# Epoch:[0][600/1224]	Loss 0.387 	Accuracy 0.438	Precison 0.438 (0.427)	Recall 0.438 (0.427)
# Epoch:[0][605/1224]	Loss 0.376 	Accuracy 0.645	Precison 0.645 (0.425)	Recall 0.645 (0.425)
# Epoch:[0][610/1224]	Loss 0.393 	Accuracy 0.609	Precison 0.609 (0.426)	Recall 0.609 (0.426)
# Epoch:[0][615/1224]	Loss 0.490 	Accuracy 0.000	Precison 0.000 (0.425)	Recall 0.000 (0.425)
# Epoch:[0][620/1224]	Loss 0.266 	Accuracy 1.000	Precison 1.000 (0.428)	Recall 1.000 (0.428)
# Epoch:[0][625/1224]	Loss 0.479 	Accuracy 0.000	Precison 0.000 (0.428)	Recall 0.000 (0.428)
# Epoch:[0][630/1224]	Loss 0.397 	Accuracy 0.348	Precison 0.348 (0.427)	Recall 0.348 (0.427)
# Epoch:[0][635/1224]	Loss 0.346 	Accuracy 0.879	Precison 0.879 (0.428)	Recall 0.879 (0.428)
# Epoch:[0][640/1224]	Loss 0.408 	Accuracy 0.336	Precison 0.336 (0.432)	Recall 0.336 (0.432)
# Epoch:[0][645/1224]	Loss 0.374 	Accuracy 0.473	Precison 0.473 (0.433)	Recall 0.473 (0.433)
# Epoch:[0][650/1224]	Loss 0.364 	Accuracy 0.590	Precison 0.590 (0.433)	Recall 0.590 (0.433)
# Epoch:[0][655/1224]	Loss 0.473 	Accuracy 0.172	Precison 0.172 (0.432)	Recall 0.172 (0.432)
# Epoch:[0][660/1224]	Loss 0.235 	Accuracy 1.000	Precison 1.000 (0.434)	Recall 1.000 (0.434)
# Epoch:[0][665/1224]	Loss 0.227 	Accuracy 1.000	Precison 1.000 (0.438)	Recall 1.000 (0.438)
# Epoch:[0][670/1224]	Loss 0.473 	Accuracy 0.164	Precison 0.164 (0.438)	Recall 0.164 (0.438)
# Epoch:[0][675/1224]	Loss 0.408 	Accuracy 0.348	Precison 0.348 (0.438)	Recall 0.348 (0.438)
# Epoch:[0][680/1224]	Loss 0.451 	Accuracy 0.973	Precison 0.973 (0.440)	Recall 0.973 (0.440)
# Epoch:[0][685/1224]	Loss 0.522 	Accuracy 0.000	Precison 0.000 (0.440)	Recall 0.000 (0.440)
# Epoch:[0][690/1224]	Loss 0.467 	Accuracy 0.965	Precison 0.965 (0.442)	Recall 0.965 (0.442)
# Epoch:[0][695/1224]	Loss 0.365 	Accuracy 0.559	Precison 0.559 (0.441)	Recall 0.559 (0.441)
# Epoch:[0][700/1224]	Loss 0.418 	Accuracy 0.332	Precison 0.332 (0.442)	Recall 0.332 (0.442)
# Epoch:[0][705/1224]	Loss 0.382 	Accuracy 0.414	Precison 0.414 (0.442)	Recall 0.414 (0.442)
# Epoch:[0][710/1224]	Loss 0.449 	Accuracy 0.258	Precison 0.258 (0.441)	Recall 0.258 (0.441)
# Epoch:[0][715/1224]	Loss 0.500 	Accuracy 0.223	Precison 0.223 (0.440)	Recall 0.223 (0.440)
# Epoch:[0][720/1224]	Loss 0.503 	Accuracy 0.000	Precison 0.000 (0.439)	Recall 0.000 (0.439)
# Epoch:[0][725/1224]	Loss 0.395 	Accuracy 0.465	Precison 0.465 (0.439)	Recall 0.465 (0.439)
# Epoch:[0][730/1224]	Loss 0.256 	Accuracy 1.000	Precison 1.000 (0.441)	Recall 1.000 (0.441)
# Epoch:[0][735/1224]	Loss 0.479 	Accuracy 0.055	Precison 0.055 (0.441)	Recall 0.055 (0.441)
# Epoch:[0][740/1224]	Loss 0.412 	Accuracy 0.477	Precison 0.477 (0.441)	Recall 0.477 (0.441)
# Epoch:[0][745/1224]	Loss 0.429 	Accuracy 0.344	Precison 0.344 (0.440)	Recall 0.344 (0.440)
# Epoch:[0][750/1224]	Loss 0.426 	Accuracy 0.281	Precison 0.281 (0.440)	Recall 0.281 (0.440)
# Epoch:[0][755/1224]	Loss 0.490 	Accuracy 0.020	Precison 0.020 (0.440)	Recall 0.020 (0.440)
# Epoch:[0][760/1224]	Loss 0.399 	Accuracy 0.383	Precison 0.383 (0.438)	Recall 0.383 (0.438)
# Epoch:[0][765/1224]	Loss 0.260 	Accuracy 1.000	Precison 1.000 (0.440)	Recall 1.000 (0.440)
# Epoch:[0][770/1224]	Loss 0.254 	Accuracy 1.000	Precison 1.000 (0.442)	Recall 1.000 (0.442)
# Epoch:[0][775/1224]	Loss 0.410 	Accuracy 0.422	Precison 0.422 (0.443)	Recall 0.422 (0.443)
# Epoch:[0][780/1224]	Loss 0.307 	Accuracy 0.910	Precison 0.910 (0.445)	Recall 0.910 (0.445)
# Epoch:[0][785/1224]	Loss 0.373 	Accuracy 0.633	Precison 0.633 (0.445)	Recall 0.633 (0.445)
# Epoch:[0][790/1224]	Loss 0.415 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[0][795/1224]	Loss 0.449 	Accuracy 0.156	Precison 0.156 (0.445)	Recall 0.156 (0.445)
# Epoch:[0][800/1224]	Loss 0.462 	Accuracy 0.141	Precison 0.141 (0.444)	Recall 0.141 (0.444)
# Epoch:[0][805/1224]	Loss 0.343 	Accuracy 0.914	Precison 0.914 (0.443)	Recall 0.914 (0.443)
# Epoch:[0][810/1224]	Loss 0.415 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[0][815/1224]	Loss 0.415 	Accuracy 0.402	Precison 0.402 (0.446)	Recall 0.402 (0.446)
# Epoch:[0][820/1224]	Loss 0.323 	Accuracy 0.652	Precison 0.652 (0.445)	Recall 0.652 (0.445)
# Epoch:[0][825/1224]	Loss 0.505 	Accuracy 0.000	Precison 0.000 (0.444)	Recall 0.000 (0.444)
# Epoch:[0][830/1224]	Loss 0.392 	Accuracy 0.441	Precison 0.441 (0.442)	Recall 0.441 (0.442)
# Epoch:[0][835/1224]	Loss 0.441 	Accuracy 0.281	Precison 0.281 (0.440)	Recall 0.281 (0.440)
# Epoch:[0][840/1224]	Loss 0.260 	Accuracy 1.000	Precison 1.000 (0.441)	Recall 1.000 (0.441)
# Epoch:[0][845/1224]	Loss 0.403 	Accuracy 0.359	Precison 0.359 (0.441)	Recall 0.359 (0.441)
# Epoch:[0][850/1224]	Loss 0.476 	Accuracy 1.000	Precison 1.000 (0.442)	Recall 1.000 (0.442)
# Epoch:[0][855/1224]	Loss 0.483 	Accuracy 0.000	Precison 0.000 (0.440)	Recall 0.000 (0.440)
# Epoch:[0][860/1224]	Loss 0.378 	Accuracy 0.508	Precison 0.508 (0.438)	Recall 0.508 (0.438)
# Epoch:[0][865/1224]	Loss 0.415 	Accuracy 1.000	Precison 1.000 (0.440)	Recall 1.000 (0.440)
# Epoch:[0][870/1224]	Loss 0.397 	Accuracy 0.000	Precison 0.000 (0.439)	Recall 0.000 (0.439)
# Epoch:[0][875/1224]	Loss 0.305 	Accuracy 0.863	Precison 0.863 (0.440)	Recall 0.863 (0.440)
# Epoch:[0][880/1224]	Loss 0.333 	Accuracy 0.758	Precison 0.758 (0.439)	Recall 0.758 (0.439)
# Epoch:[0][885/1224]	Loss 0.392 	Accuracy 0.250	Precison 0.250 (0.439)	Recall 0.250 (0.439)
# Epoch:[0][890/1224]	Loss 0.403 	Accuracy 0.352	Precison 0.352 (0.439)	Recall 0.352 (0.439)
# Epoch:[0][895/1224]	Loss 0.399 	Accuracy 0.312	Precison 0.312 (0.438)	Recall 0.312 (0.438)
# Epoch:[0][900/1224]	Loss 0.435 	Accuracy 0.023	Precison 0.023 (0.437)	Recall 0.023 (0.437)
# Epoch:[0][905/1224]	Loss 0.407 	Accuracy 0.188	Precison 0.188 (0.436)	Recall 0.188 (0.436)
# Epoch:[0][910/1224]	Loss 0.440 	Accuracy 0.918	Precison 0.918 (0.437)	Recall 0.918 (0.437)
# Epoch:[0][915/1224]	Loss 0.463 	Accuracy 1.000	Precison 1.000 (0.439)	Recall 1.000 (0.439)
# Epoch:[0][920/1224]	Loss 0.378 	Accuracy 0.453	Precison 0.453 (0.441)	Recall 0.453 (0.441)
# Epoch:[0][925/1224]	Loss 0.422 	Accuracy 0.289	Precison 0.289 (0.441)	Recall 0.289 (0.441)
# Epoch:[0][930/1224]	Loss 0.422 	Accuracy 0.297	Precison 0.297 (0.441)	Recall 0.297 (0.441)
# Epoch:[0][935/1224]	Loss 0.486 	Accuracy 0.027	Precison 0.027 (0.440)	Recall 0.027 (0.440)
# Epoch:[0][940/1224]	Loss 0.423 	Accuracy 1.000	Precison 1.000 (0.441)	Recall 1.000 (0.441)
# Epoch:[0][945/1224]	Loss 0.299 	Accuracy 1.000	Precison 1.000 (0.441)	Recall 1.000 (0.441)
# Epoch:[0][950/1224]	Loss 0.495 	Accuracy 0.000	Precison 0.000 (0.439)	Recall 0.000 (0.439)
# Epoch:[0][955/1224]	Loss 0.331 	Accuracy 0.738	Precison 0.738 (0.439)	Recall 0.738 (0.439)
# Epoch:[0][960/1224]	Loss 0.309 	Accuracy 0.859	Precison 0.859 (0.439)	Recall 0.859 (0.439)
# Epoch:[0][965/1224]	Loss 0.396 	Accuracy 0.230	Precison 0.230 (0.439)	Recall 0.230 (0.439)
# Epoch:[0][970/1224]	Loss 0.355 	Accuracy 0.527	Precison 0.527 (0.441)	Recall 0.527 (0.441)
# Epoch:[0][975/1224]	Loss 0.295 	Accuracy 0.914	Precison 0.914 (0.441)	Recall 0.914 (0.441)
# Epoch:[0][980/1224]	Loss 0.323 	Accuracy 1.000	Precison 1.000 (0.444)	Recall 1.000 (0.444)
# Epoch:[0][985/1224]	Loss 0.318 	Accuracy 0.688	Precison 0.688 (0.444)	Recall 0.688 (0.444)
# Epoch:[0][990/1224]	Loss 0.429 	Accuracy 0.289	Precison 0.289 (0.444)	Recall 0.289 (0.444)
# Epoch:[0][995/1224]	Loss 0.338 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[0][1000/1224]	Loss 0.336 	Accuracy 0.699	Precison 0.699 (0.447)	Recall 0.699 (0.447)
# Epoch:[0][1005/1224]	Loss 0.455 	Accuracy 0.020	Precison 0.020 (0.447)	Recall 0.020 (0.447)
# Epoch:[0][1010/1224]	Loss 0.512 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[0][1015/1224]	Loss 0.236 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[0][1020/1224]	Loss 0.404 	Accuracy 0.367	Precison 0.367 (0.447)	Recall 0.367 (0.447)
# Epoch:[0][1025/1224]	Loss 0.362 	Accuracy 0.656	Precison 0.656 (0.447)	Recall 0.656 (0.447)
# Epoch:[0][1030/1224]	Loss 0.511 	Accuracy 0.000	Precison 0.000 (0.446)	Recall 0.000 (0.446)
# Epoch:[0][1035/1224]	Loss 0.372 	Accuracy 0.508	Precison 0.508 (0.445)	Recall 0.508 (0.445)
# Epoch:[0][1040/1224]	Loss 0.503 	Accuracy 0.004	Precison 0.004 (0.446)	Recall 0.004 (0.446)
# Epoch:[0][1045/1224]	Loss 0.332 	Accuracy 0.770	Precison 0.770 (0.446)	Recall 0.770 (0.446)
# Epoch:[0][1050/1224]	Loss 0.263 	Accuracy 0.996	Precison 0.996 (0.447)	Recall 0.996 (0.447)
# Epoch:[0][1055/1224]	Loss 0.447 	Accuracy 0.309	Precison 0.309 (0.446)	Recall 0.309 (0.446)
# Epoch:[0][1060/1224]	Loss 0.368 	Accuracy 0.574	Precison 0.574 (0.446)	Recall 0.574 (0.446)
# Epoch:[0][1065/1224]	Loss 0.338 	Accuracy 0.699	Precison 0.699 (0.449)	Recall 0.699 (0.449)
# Epoch:[0][1070/1224]	Loss 0.397 	Accuracy 0.348	Precison 0.348 (0.448)	Recall 0.348 (0.448)
# Epoch:[0][1075/1224]	Loss 0.481 	Accuracy 0.000	Precison 0.000 (0.447)	Recall 0.000 (0.447)
# Epoch:[0][1080/1224]	Loss 0.506 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[0][1085/1224]	Loss 0.336 	Accuracy 0.633	Precison 0.633 (0.444)	Recall 0.633 (0.444)
# Epoch:[0][1090/1224]	Loss 0.435 	Accuracy 0.172	Precison 0.172 (0.444)	Recall 0.172 (0.444)
# Epoch:[0][1095/1224]	Loss 0.249 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[0][1100/1224]	Loss 0.439 	Accuracy 0.355	Precison 0.355 (0.446)	Recall 0.355 (0.446)
# Epoch:[0][1105/1224]	Loss 0.487 	Accuracy 0.086	Precison 0.086 (0.447)	Recall 0.086 (0.447)
# Epoch:[0][1110/1224]	Loss 0.415 	Accuracy 0.137	Precison 0.137 (0.445)	Recall 0.137 (0.445)
# Epoch:[0][1115/1224]	Loss 0.409 	Accuracy 0.395	Precison 0.395 (0.445)	Recall 0.395 (0.445)
# Epoch:[0][1120/1224]	Loss 0.375 	Accuracy 0.477	Precison 0.477 (0.444)	Recall 0.477 (0.444)
# Epoch:[0][1125/1224]	Loss 0.492 	Accuracy 0.090	Precison 0.090 (0.444)	Recall 0.090 (0.444)
# Epoch:[0][1130/1224]	Loss 0.461 	Accuracy 0.152	Precison 0.152 (0.443)	Recall 0.152 (0.443)
# Epoch:[0][1135/1224]	Loss 0.417 	Accuracy 1.000	Precison 1.000 (0.443)	Recall 1.000 (0.443)
# Epoch:[0][1140/1224]	Loss 0.417 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[0][1145/1224]	Loss 0.391 	Accuracy 0.445	Precison 0.445 (0.447)	Recall 0.445 (0.447)
# Epoch:[0][1150/1224]	Loss 0.368 	Accuracy 0.500	Precison 0.500 (0.448)	Recall 0.500 (0.448)
# Epoch:[0][1155/1224]	Loss 0.449 	Accuracy 0.117	Precison 0.117 (0.447)	Recall 0.117 (0.447)
# Epoch:[0][1160/1224]	Loss 0.463 	Accuracy 0.344	Precison 0.344 (0.447)	Recall 0.344 (0.447)
# Epoch:[0][1165/1224]	Loss 0.300 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[0][1170/1224]	Loss 0.502 	Accuracy 0.000	Precison 0.000 (0.447)	Recall 0.000 (0.447)
# Epoch:[0][1175/1224]	Loss 0.284 	Accuracy 0.941	Precison 0.941 (0.447)	Recall 0.941 (0.447)
# Epoch:[0][1180/1224]	Loss 0.368 	Accuracy 0.652	Precison 0.652 (0.446)	Recall 0.652 (0.446)
# Epoch:[0][1185/1224]	Loss 0.400 	Accuracy 0.426	Precison 0.426 (0.446)	Recall 0.426 (0.446)
# Epoch:[0][1190/1224]	Loss 0.316 	Accuracy 0.676	Precison 0.676 (0.446)	Recall 0.676 (0.446)
# Epoch:[0][1195/1224]	Loss 0.474 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[0][1200/1224]	Loss 0.328 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[0][1205/1224]	Loss 0.495 	Accuracy 0.000	Precison 0.000 (0.449)	Recall 0.000 (0.449)
# Epoch:[0][1210/1224]	Loss 0.370 	Accuracy 0.574	Precison 0.574 (0.449)	Recall 0.574 (0.449)
# Epoch:[0][1215/1224]	Loss 0.463 	Accuracy 0.148	Precison 0.148 (0.449)	Recall 0.148 (0.449)
# Epoch:[0][1220/1224]	Loss 0.411 	Accuracy 0.262	Precison 0.262 (0.449)	Recall 0.262 (0.449)
# Epoch:[1][0/1224]	Loss 0.427 	Accuracy 0.395	Precison 0.395 (0.448)	Recall 0.395 (0.448)
# Epoch:[1][5/1224]	Loss 0.364 	Accuracy 0.531	Precison 0.531 (0.448)	Recall 0.531 (0.448)
# Epoch:[1][10/1224]	Loss 0.388 	Accuracy 0.613	Precison 0.613 (0.448)	Recall 0.613 (0.448)
# Epoch:[1][15/1224]	Loss 0.435 	Accuracy 0.281	Precison 0.281 (0.447)	Recall 0.281 (0.447)
# Epoch:[1][20/1224]	Loss 0.454 	Accuracy 0.316	Precison 0.316 (0.446)	Recall 0.316 (0.446)
# Epoch:[1][25/1224]	Loss 0.396 	Accuracy 0.707	Precison 0.707 (0.446)	Recall 0.707 (0.446)
# Epoch:[1][30/1224]	Loss 0.495 	Accuracy 0.000	Precison 0.000 (0.446)	Recall 0.000 (0.446)
# Epoch:[1][35/1224]	Loss 0.389 	Accuracy 0.781	Precison 0.781 (0.447)	Recall 0.781 (0.447)
# Epoch:[1][40/1224]	Loss 0.392 	Accuracy 0.547	Precison 0.547 (0.448)	Recall 0.547 (0.448)
# Epoch:[1][45/1224]	Loss 0.405 	Accuracy 0.398	Precison 0.398 (0.448)	Recall 0.398 (0.448)
# Epoch:[1][50/1224]	Loss 0.405 	Accuracy 0.344	Precison 0.344 (0.447)	Recall 0.344 (0.447)
# Epoch:[1][55/1224]	Loss 0.399 	Accuracy 0.465	Precison 0.465 (0.447)	Recall 0.465 (0.447)
# Epoch:[1][60/1224]	Loss 0.345 	Accuracy 0.645	Precison 0.645 (0.447)	Recall 0.645 (0.447)
# Epoch:[1][65/1224]	Loss 0.351 	Accuracy 0.965	Precison 0.965 (0.448)	Recall 0.965 (0.448)
# Epoch:[1][70/1224]	Loss 0.394 	Accuracy 0.391	Precison 0.391 (0.448)	Recall 0.391 (0.448)
# Epoch:[1][75/1224]	Loss 0.396 	Accuracy 0.344	Precison 0.344 (0.448)	Recall 0.344 (0.448)
# Epoch:[1][80/1224]	Loss 0.426 	Accuracy 0.336	Precison 0.336 (0.448)	Recall 0.336 (0.448)
# Epoch:[1][85/1224]	Loss 0.407 	Accuracy 0.324	Precison 0.324 (0.447)	Recall 0.324 (0.447)
# Epoch:[1][90/1224]	Loss 0.326 	Accuracy 0.645	Precison 0.645 (0.447)	Recall 0.645 (0.447)
# Epoch:[1][95/1224]	Loss 0.374 	Accuracy 0.355	Precison 0.355 (0.448)	Recall 0.355 (0.448)
# Epoch:[1][100/1224]	Loss 0.367 	Accuracy 0.973	Precison 0.973 (0.449)	Recall 0.973 (0.449)
# Epoch:[1][105/1224]	Loss 0.408 	Accuracy 0.379	Precison 0.379 (0.448)	Recall 0.379 (0.448)
# Epoch:[1][110/1224]	Loss 0.470 	Accuracy 0.238	Precison 0.238 (0.448)	Recall 0.238 (0.448)
# Epoch:[1][115/1224]	Loss 0.483 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[1][120/1224]	Loss 0.338 	Accuracy 0.695	Precison 0.695 (0.449)	Recall 0.695 (0.449)
# Epoch:[1][125/1224]	Loss 0.354 	Accuracy 0.609	Precison 0.609 (0.448)	Recall 0.609 (0.448)
# Epoch:[1][130/1224]	Loss 0.317 	Accuracy 0.738	Precison 0.738 (0.449)	Recall 0.738 (0.449)
# Epoch:[1][135/1224]	Loss 0.359 	Accuracy 0.500	Precison 0.500 (0.450)	Recall 0.500 (0.450)
# Epoch:[1][140/1224]	Loss 0.503 	Accuracy 0.000	Precison 0.000 (0.449)	Recall 0.000 (0.449)
# Epoch:[1][145/1224]	Loss 0.270 	Accuracy 0.973	Precison 0.973 (0.451)	Recall 0.973 (0.451)
# Epoch:[1][150/1224]	Loss 0.485 	Accuracy 0.086	Precison 0.086 (0.450)	Recall 0.086 (0.450)
# Epoch:[1][155/1224]	Loss 0.509 	Accuracy 0.000	Precison 0.000 (0.450)	Recall 0.000 (0.450)
# Epoch:[1][160/1224]	Loss 0.385 	Accuracy 0.605	Precison 0.605 (0.450)	Recall 0.605 (0.450)
# Epoch:[1][165/1224]	Loss 0.315 	Accuracy 0.750	Precison 0.750 (0.450)	Recall 0.750 (0.450)
# Epoch:[1][170/1224]	Loss 0.307 	Accuracy 0.691	Precison 0.691 (0.450)	Recall 0.691 (0.450)
# Epoch:[1][175/1224]	Loss 0.419 	Accuracy 1.000	Precison 1.000 (0.449)	Recall 1.000 (0.449)
# Epoch:[1][180/1224]	Loss 0.506 	Accuracy 0.000	Precison 0.000 (0.448)	Recall 0.000 (0.448)
# Epoch:[1][185/1224]	Loss 0.421 	Accuracy 0.016	Precison 0.016 (0.446)	Recall 0.016 (0.446)
# Epoch:[1][190/1224]	Loss 0.389 	Accuracy 0.078	Precison 0.078 (0.446)	Recall 0.078 (0.446)
# Epoch:[1][195/1224]	Loss 0.459 	Accuracy 0.168	Precison 0.168 (0.446)	Recall 0.168 (0.446)
# Epoch:[1][200/1224]	Loss 0.362 	Accuracy 0.590	Precison 0.590 (0.446)	Recall 0.590 (0.446)
# Epoch:[1][205/1224]	Loss 0.387 	Accuracy 0.855	Precison 0.855 (0.447)	Recall 0.855 (0.447)
# Epoch:[1][210/1224]	Loss 0.285 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[1][215/1224]	Loss 0.496 	Accuracy 0.000	Precison 0.000 (0.447)	Recall 0.000 (0.447)
# Epoch:[1][220/1224]	Loss 0.372 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][225/1224]	Loss 0.357 	Accuracy 0.023	Precison 0.023 (0.444)	Recall 0.023 (0.444)
# Epoch:[1][230/1224]	Loss 0.444 	Accuracy 0.520	Precison 0.520 (0.443)	Recall 0.520 (0.443)
# Epoch:[1][235/1224]	Loss 0.425 	Accuracy 0.219	Precison 0.219 (0.443)	Recall 0.219 (0.443)
# Epoch:[1][240/1224]	Loss 0.310 	Accuracy 1.000	Precison 1.000 (0.444)	Recall 1.000 (0.444)
# Epoch:[1][245/1224]	Loss 0.495 	Accuracy 0.848	Precison 0.848 (0.445)	Recall 0.848 (0.445)
# Epoch:[1][250/1224]	Loss 0.423 	Accuracy 0.105	Precison 0.105 (0.445)	Recall 0.105 (0.445)
# Epoch:[1][255/1224]	Loss 0.452 	Accuracy 0.246	Precison 0.246 (0.445)	Recall 0.246 (0.445)
# Epoch:[1][260/1224]	Loss 0.379 	Accuracy 0.285	Precison 0.285 (0.445)	Recall 0.285 (0.445)
# Epoch:[1][265/1224]	Loss 0.334 	Accuracy 0.660	Precison 0.660 (0.445)	Recall 0.660 (0.445)
# Epoch:[1][270/1224]	Loss 0.330 	Accuracy 0.660	Precison 0.660 (0.445)	Recall 0.660 (0.445)
# Epoch:[1][275/1224]	Loss 0.365 	Accuracy 0.465	Precison 0.465 (0.445)	Recall 0.465 (0.445)
# Epoch:[1][280/1224]	Loss 0.417 	Accuracy 0.449	Precison 0.449 (0.444)	Recall 0.449 (0.444)
# Epoch:[1][285/1224]	Loss 0.350 	Accuracy 0.645	Precison 0.645 (0.444)	Recall 0.645 (0.444)
# Epoch:[1][290/1224]	Loss 0.388 	Accuracy 0.219	Precison 0.219 (0.444)	Recall 0.219 (0.444)
# Epoch:[1][295/1224]	Loss 0.382 	Accuracy 0.387	Precison 0.387 (0.444)	Recall 0.387 (0.444)
# Epoch:[1][300/1224]	Loss 0.442 	Accuracy 0.379	Precison 0.379 (0.444)	Recall 0.379 (0.444)
# Epoch:[1][305/1224]	Loss 0.385 	Accuracy 0.785	Precison 0.785 (0.445)	Recall 0.785 (0.445)
# Epoch:[1][310/1224]	Loss 0.345 	Accuracy 0.961	Precison 0.961 (0.446)	Recall 0.961 (0.446)
# Epoch:[1][315/1224]	Loss 0.360 	Accuracy 0.605	Precison 0.605 (0.446)	Recall 0.605 (0.446)
# Epoch:[1][320/1224]	Loss 0.396 	Accuracy 0.449	Precison 0.449 (0.447)	Recall 0.449 (0.447)
# Epoch:[1][325/1224]	Loss 0.396 	Accuracy 0.410	Precison 0.410 (0.447)	Recall 0.410 (0.447)
# Epoch:[1][330/1224]	Loss 0.259 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[1][335/1224]	Loss 0.368 	Accuracy 0.285	Precison 0.285 (0.446)	Recall 0.285 (0.446)
# Epoch:[1][340/1224]	Loss 0.490 	Accuracy 0.070	Precison 0.070 (0.446)	Recall 0.070 (0.446)
# Epoch:[1][345/1224]	Loss 0.354 	Accuracy 0.398	Precison 0.398 (0.446)	Recall 0.398 (0.446)
# Epoch:[1][350/1224]	Loss 0.355 	Accuracy 0.566	Precison 0.566 (0.446)	Recall 0.566 (0.446)
# Epoch:[1][355/1224]	Loss 0.368 	Accuracy 0.484	Precison 0.484 (0.446)	Recall 0.484 (0.446)
# Epoch:[1][360/1224]	Loss 0.291 	Accuracy 0.930	Precison 0.930 (0.447)	Recall 0.930 (0.447)
# Epoch:[1][365/1224]	Loss 0.519 	Accuracy 0.000	Precison 0.000 (0.446)	Recall 0.000 (0.446)
# Epoch:[1][370/1224]	Loss 0.397 	Accuracy 0.387	Precison 0.387 (0.446)	Recall 0.387 (0.446)
# Epoch:[1][375/1224]	Loss 0.383 	Accuracy 0.406	Precison 0.406 (0.446)	Recall 0.406 (0.446)
# Epoch:[1][380/1224]	Loss 0.391 	Accuracy 0.359	Precison 0.359 (0.446)	Recall 0.359 (0.446)
# Epoch:[1][385/1224]	Loss 0.350 	Accuracy 0.598	Precison 0.598 (0.445)	Recall 0.598 (0.445)
# Epoch:[1][390/1224]	Loss 0.408 	Accuracy 0.406	Precison 0.406 (0.445)	Recall 0.406 (0.445)
# Epoch:[1][395/1224]	Loss 0.324 	Accuracy 0.578	Precison 0.578 (0.445)	Recall 0.578 (0.445)
# Epoch:[1][400/1224]	Loss 0.366 	Accuracy 0.551	Precison 0.551 (0.445)	Recall 0.551 (0.445)
# Epoch:[1][405/1224]	Loss 0.367 	Accuracy 0.418	Precison 0.418 (0.445)	Recall 0.418 (0.445)
# Epoch:[1][410/1224]	Loss 0.449 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][415/1224]	Loss 0.479 	Accuracy 0.309	Precison 0.309 (0.444)	Recall 0.309 (0.444)
# Epoch:[1][420/1224]	Loss 0.492 	Accuracy 0.062	Precison 0.062 (0.444)	Recall 0.062 (0.444)
# Epoch:[1][425/1224]	Loss 0.288 	Accuracy 0.773	Precison 0.773 (0.444)	Recall 0.773 (0.444)
# Epoch:[1][430/1224]	Loss 0.471 	Accuracy 0.203	Precison 0.203 (0.443)	Recall 0.203 (0.443)
# Epoch:[1][435/1224]	Loss 0.384 	Accuracy 0.000	Precison 0.000 (0.442)	Recall 0.000 (0.442)
# Epoch:[1][440/1224]	Loss 0.454 	Accuracy 0.312	Precison 0.312 (0.443)	Recall 0.312 (0.443)
# Epoch:[1][445/1224]	Loss 0.502 	Accuracy 0.000	Precison 0.000 (0.442)	Recall 0.000 (0.442)
# Epoch:[1][450/1224]	Loss 0.476 	Accuracy 0.105	Precison 0.105 (0.442)	Recall 0.105 (0.442)
# Epoch:[1][455/1224]	Loss 0.497 	Accuracy 0.000	Precison 0.000 (0.442)	Recall 0.000 (0.442)
# Epoch:[1][460/1224]	Loss 0.494 	Accuracy 0.000	Precison 0.000 (0.441)	Recall 0.000 (0.441)
# Epoch:[1][465/1224]	Loss 0.344 	Accuracy 0.531	Precison 0.531 (0.441)	Recall 0.531 (0.441)
# Epoch:[1][470/1224]	Loss 0.375 	Accuracy 0.000	Precison 0.000 (0.440)	Recall 0.000 (0.440)
# Epoch:[1][475/1224]	Loss 0.284 	Accuracy 1.000	Precison 1.000 (0.440)	Recall 1.000 (0.440)
# Epoch:[1][480/1224]	Loss 0.386 	Accuracy 0.551	Precison 0.551 (0.441)	Recall 0.551 (0.441)
# Epoch:[1][485/1224]	Loss 0.360 	Accuracy 0.977	Precison 0.977 (0.442)	Recall 0.977 (0.442)
# Epoch:[1][490/1224]	Loss 0.492 	Accuracy 0.012	Precison 0.012 (0.441)	Recall 0.012 (0.441)
# Epoch:[1][495/1224]	Loss 0.353 	Accuracy 1.000	Precison 1.000 (0.443)	Recall 1.000 (0.443)
# Epoch:[1][500/1224]	Loss 0.414 	Accuracy 0.996	Precison 0.996 (0.444)	Recall 0.996 (0.444)
# Epoch:[1][505/1224]	Loss 0.332 	Accuracy 0.914	Precison 0.914 (0.446)	Recall 0.914 (0.446)
# Epoch:[1][510/1224]	Loss 0.414 	Accuracy 0.324	Precison 0.324 (0.446)	Recall 0.324 (0.446)
# Epoch:[1][515/1224]	Loss 0.486 	Accuracy 0.160	Precison 0.160 (0.446)	Recall 0.160 (0.446)
# Epoch:[1][520/1224]	Loss 0.309 	Accuracy 0.777	Precison 0.777 (0.446)	Recall 0.777 (0.446)
# Epoch:[1][525/1224]	Loss 0.422 	Accuracy 0.418	Precison 0.418 (0.446)	Recall 0.418 (0.446)
# Epoch:[1][530/1224]	Loss 0.507 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][535/1224]	Loss 0.506 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][540/1224]	Loss 0.425 	Accuracy 0.223	Precison 0.223 (0.445)	Recall 0.223 (0.445)
# Epoch:[1][545/1224]	Loss 0.388 	Accuracy 0.438	Precison 0.438 (0.445)	Recall 0.438 (0.445)
# Epoch:[1][550/1224]	Loss 0.505 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][555/1224]	Loss 0.484 	Accuracy 0.070	Precison 0.070 (0.444)	Recall 0.070 (0.444)
# Epoch:[1][560/1224]	Loss 0.459 	Accuracy 0.164	Precison 0.164 (0.443)	Recall 0.164 (0.443)
# Epoch:[1][565/1224]	Loss 0.498 	Accuracy 0.000	Precison 0.000 (0.442)	Recall 0.000 (0.442)
# Epoch:[1][570/1224]	Loss 0.493 	Accuracy 0.000	Precison 0.000 (0.441)	Recall 0.000 (0.441)
# Epoch:[1][575/1224]	Loss 0.317 	Accuracy 0.832	Precison 0.832 (0.441)	Recall 0.832 (0.441)
# Epoch:[1][580/1224]	Loss 0.386 	Accuracy 0.438	Precison 0.438 (0.441)	Recall 0.438 (0.441)
# Epoch:[1][585/1224]	Loss 0.325 	Accuracy 0.793	Precison 0.793 (0.441)	Recall 0.793 (0.441)
# Epoch:[1][590/1224]	Loss 0.428 	Accuracy 0.199	Precison 0.199 (0.441)	Recall 0.199 (0.441)
# Epoch:[1][595/1224]	Loss 0.387 	Accuracy 0.328	Precison 0.328 (0.441)	Recall 0.328 (0.441)
# Epoch:[1][600/1224]	Loss 0.387 	Accuracy 0.438	Precison 0.438 (0.442)	Recall 0.438 (0.442)
# Epoch:[1][605/1224]	Loss 0.376 	Accuracy 0.645	Precison 0.645 (0.441)	Recall 0.645 (0.441)
# Epoch:[1][610/1224]	Loss 0.392 	Accuracy 0.609	Precison 0.609 (0.442)	Recall 0.609 (0.442)
# Epoch:[1][615/1224]	Loss 0.491 	Accuracy 0.000	Precison 0.000 (0.441)	Recall 0.000 (0.441)
# Epoch:[1][620/1224]	Loss 0.265 	Accuracy 1.000	Precison 1.000 (0.442)	Recall 1.000 (0.442)
# Epoch:[1][625/1224]	Loss 0.479 	Accuracy 0.000	Precison 0.000 (0.442)	Recall 0.000 (0.442)
# Epoch:[1][630/1224]	Loss 0.397 	Accuracy 0.348	Precison 0.348 (0.442)	Recall 0.348 (0.442)
# Epoch:[1][635/1224]	Loss 0.346 	Accuracy 0.879	Precison 0.879 (0.442)	Recall 0.879 (0.442)
# Epoch:[1][640/1224]	Loss 0.408 	Accuracy 0.336	Precison 0.336 (0.443)	Recall 0.336 (0.443)
# Epoch:[1][645/1224]	Loss 0.374 	Accuracy 0.473	Precison 0.473 (0.444)	Recall 0.473 (0.444)
# Epoch:[1][650/1224]	Loss 0.364 	Accuracy 0.590	Precison 0.590 (0.444)	Recall 0.590 (0.444)
# Epoch:[1][655/1224]	Loss 0.472 	Accuracy 0.172	Precison 0.172 (0.443)	Recall 0.172 (0.443)
# Epoch:[1][660/1224]	Loss 0.234 	Accuracy 1.000	Precison 1.000 (0.444)	Recall 1.000 (0.444)
# Epoch:[1][665/1224]	Loss 0.227 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[1][670/1224]	Loss 0.473 	Accuracy 0.164	Precison 0.164 (0.445)	Recall 0.164 (0.445)
# Epoch:[1][675/1224]	Loss 0.407 	Accuracy 0.348	Precison 0.348 (0.446)	Recall 0.348 (0.446)
# Epoch:[1][680/1224]	Loss 0.450 	Accuracy 0.973	Precison 0.973 (0.446)	Recall 0.973 (0.446)
# Epoch:[1][685/1224]	Loss 0.521 	Accuracy 0.000	Precison 0.000 (0.446)	Recall 0.000 (0.446)
# Epoch:[1][690/1224]	Loss 0.467 	Accuracy 0.965	Precison 0.965 (0.447)	Recall 0.965 (0.447)
# Epoch:[1][695/1224]	Loss 0.365 	Accuracy 0.559	Precison 0.559 (0.447)	Recall 0.559 (0.447)
# Epoch:[1][700/1224]	Loss 0.417 	Accuracy 0.332	Precison 0.332 (0.447)	Recall 0.332 (0.447)
# Epoch:[1][705/1224]	Loss 0.382 	Accuracy 0.414	Precison 0.414 (0.447)	Recall 0.414 (0.447)
# Epoch:[1][710/1224]	Loss 0.449 	Accuracy 0.258	Precison 0.258 (0.446)	Recall 0.258 (0.446)
# Epoch:[1][715/1224]	Loss 0.500 	Accuracy 0.223	Precison 0.223 (0.446)	Recall 0.223 (0.446)
# Epoch:[1][720/1224]	Loss 0.504 	Accuracy 0.000	Precison 0.000 (0.446)	Recall 0.000 (0.446)
# Epoch:[1][725/1224]	Loss 0.395 	Accuracy 0.465	Precison 0.465 (0.446)	Recall 0.465 (0.446)
# Epoch:[1][730/1224]	Loss 0.254 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][735/1224]	Loss 0.480 	Accuracy 0.055	Precison 0.055 (0.446)	Recall 0.055 (0.446)
# Epoch:[1][740/1224]	Loss 0.412 	Accuracy 0.477	Precison 0.477 (0.446)	Recall 0.477 (0.446)
# Epoch:[1][745/1224]	Loss 0.429 	Accuracy 0.344	Precison 0.344 (0.446)	Recall 0.344 (0.446)
# Epoch:[1][750/1224]	Loss 0.426 	Accuracy 0.281	Precison 0.281 (0.446)	Recall 0.281 (0.446)
# Epoch:[1][755/1224]	Loss 0.491 	Accuracy 0.020	Precison 0.020 (0.446)	Recall 0.020 (0.446)
# Epoch:[1][760/1224]	Loss 0.399 	Accuracy 0.383	Precison 0.383 (0.445)	Recall 0.383 (0.445)
# Epoch:[1][765/1224]	Loss 0.258 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][770/1224]	Loss 0.252 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][775/1224]	Loss 0.410 	Accuracy 0.422	Precison 0.422 (0.447)	Recall 0.422 (0.447)
# Epoch:[1][780/1224]	Loss 0.306 	Accuracy 0.910	Precison 0.910 (0.448)	Recall 0.910 (0.448)
# Epoch:[1][785/1224]	Loss 0.373 	Accuracy 0.633	Precison 0.633 (0.448)	Recall 0.633 (0.448)
# Epoch:[1][790/1224]	Loss 0.415 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[1][795/1224]	Loss 0.449 	Accuracy 0.156	Precison 0.156 (0.448)	Recall 0.156 (0.448)
# Epoch:[1][800/1224]	Loss 0.462 	Accuracy 0.141	Precison 0.141 (0.447)	Recall 0.141 (0.447)
# Epoch:[1][805/1224]	Loss 0.343 	Accuracy 0.914	Precison 0.914 (0.447)	Recall 0.914 (0.447)
# Epoch:[1][810/1224]	Loss 0.415 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[1][815/1224]	Loss 0.415 	Accuracy 0.402	Precison 0.402 (0.448)	Recall 0.402 (0.448)
# Epoch:[1][820/1224]	Loss 0.322 	Accuracy 0.652	Precison 0.652 (0.448)	Recall 0.652 (0.448)
# Epoch:[1][825/1224]	Loss 0.506 	Accuracy 0.000	Precison 0.000 (0.447)	Recall 0.000 (0.447)
# Epoch:[1][830/1224]	Loss 0.392 	Accuracy 0.441	Precison 0.441 (0.447)	Recall 0.441 (0.447)
# Epoch:[1][835/1224]	Loss 0.441 	Accuracy 0.281	Precison 0.281 (0.446)	Recall 0.281 (0.446)
# Epoch:[1][840/1224]	Loss 0.259 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][845/1224]	Loss 0.403 	Accuracy 0.359	Precison 0.359 (0.446)	Recall 0.359 (0.446)
# Epoch:[1][850/1224]	Loss 0.476 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][855/1224]	Loss 0.483 	Accuracy 0.000	Precison 0.000 (0.446)	Recall 0.000 (0.446)
# Epoch:[1][860/1224]	Loss 0.377 	Accuracy 0.508	Precison 0.508 (0.445)	Recall 0.508 (0.445)
# Epoch:[1][865/1224]	Loss 0.415 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][870/1224]	Loss 0.397 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][875/1224]	Loss 0.304 	Accuracy 0.863	Precison 0.863 (0.445)	Recall 0.863 (0.445)
# Epoch:[1][880/1224]	Loss 0.331 	Accuracy 0.758	Precison 0.758 (0.445)	Recall 0.758 (0.445)
# Epoch:[1][885/1224]	Loss 0.392 	Accuracy 0.250	Precison 0.250 (0.445)	Recall 0.250 (0.445)
# Epoch:[1][890/1224]	Loss 0.403 	Accuracy 0.352	Precison 0.352 (0.445)	Recall 0.352 (0.445)
# Epoch:[1][895/1224]	Loss 0.399 	Accuracy 0.312	Precison 0.312 (0.445)	Recall 0.312 (0.445)
# Epoch:[1][900/1224]	Loss 0.435 	Accuracy 0.023	Precison 0.023 (0.444)	Recall 0.023 (0.444)
# Epoch:[1][905/1224]	Loss 0.408 	Accuracy 0.188	Precison 0.188 (0.444)	Recall 0.188 (0.444)
# Epoch:[1][910/1224]	Loss 0.439 	Accuracy 0.918	Precison 0.918 (0.444)	Recall 0.918 (0.444)
# Epoch:[1][915/1224]	Loss 0.462 	Accuracy 1.000	Precison 1.000 (0.445)	Recall 1.000 (0.445)
# Epoch:[1][920/1224]	Loss 0.378 	Accuracy 0.453	Precison 0.453 (0.446)	Recall 0.453 (0.446)
# Epoch:[1][925/1224]	Loss 0.422 	Accuracy 0.289	Precison 0.289 (0.446)	Recall 0.289 (0.446)
# Epoch:[1][930/1224]	Loss 0.422 	Accuracy 0.297	Precison 0.297 (0.446)	Recall 0.297 (0.446)
# Epoch:[1][935/1224]	Loss 0.486 	Accuracy 0.027	Precison 0.027 (0.446)	Recall 0.027 (0.446)
# Epoch:[1][940/1224]	Loss 0.423 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][945/1224]	Loss 0.298 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][950/1224]	Loss 0.495 	Accuracy 0.000	Precison 0.000 (0.445)	Recall 0.000 (0.445)
# Epoch:[1][955/1224]	Loss 0.331 	Accuracy 0.738	Precison 0.738 (0.445)	Recall 0.738 (0.445)
# Epoch:[1][960/1224]	Loss 0.309 	Accuracy 0.859	Precison 0.859 (0.445)	Recall 0.859 (0.445)
# Epoch:[1][965/1224]	Loss 0.396 	Accuracy 0.230	Precison 0.230 (0.445)	Recall 0.230 (0.445)
# Epoch:[1][970/1224]	Loss 0.355 	Accuracy 0.527	Precison 0.527 (0.446)	Recall 0.527 (0.446)
# Epoch:[1][975/1224]	Loss 0.295 	Accuracy 0.914	Precison 0.914 (0.446)	Recall 0.914 (0.446)
# Epoch:[1][980/1224]	Loss 0.323 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[1][985/1224]	Loss 0.318 	Accuracy 0.688	Precison 0.688 (0.447)	Recall 0.688 (0.447)
# Epoch:[1][990/1224]	Loss 0.428 	Accuracy 0.289	Precison 0.289 (0.447)	Recall 0.289 (0.447)
# Epoch:[1][995/1224]	Loss 0.338 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[1][1000/1224]	Loss 0.336 	Accuracy 0.699	Precison 0.699 (0.448)	Recall 0.699 (0.448)
# Epoch:[1][1005/1224]	Loss 0.454 	Accuracy 0.020	Precison 0.020 (0.448)	Recall 0.020 (0.448)
# Epoch:[1][1010/1224]	Loss 0.511 	Accuracy 0.000	Precison 0.000 (0.447)	Recall 0.000 (0.447)
# Epoch:[1][1015/1224]	Loss 0.235 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[1][1020/1224]	Loss 0.404 	Accuracy 0.367	Precison 0.367 (0.448)	Recall 0.367 (0.448)
# Epoch:[1][1025/1224]	Loss 0.362 	Accuracy 0.656	Precison 0.656 (0.448)	Recall 0.656 (0.448)
# Epoch:[1][1030/1224]	Loss 0.510 	Accuracy 0.000	Precison 0.000 (0.448)	Recall 0.000 (0.448)
# Epoch:[1][1035/1224]	Loss 0.371 	Accuracy 0.508	Precison 0.508 (0.447)	Recall 0.508 (0.447)
# Epoch:[1][1040/1224]	Loss 0.503 	Accuracy 0.004	Precison 0.004 (0.448)	Recall 0.004 (0.448)
# Epoch:[1][1045/1224]	Loss 0.332 	Accuracy 0.770	Precison 0.770 (0.448)	Recall 0.770 (0.448)
# Epoch:[1][1050/1224]	Loss 0.263 	Accuracy 0.996	Precison 0.996 (0.448)	Recall 0.996 (0.448)
# Epoch:[1][1055/1224]	Loss 0.447 	Accuracy 0.309	Precison 0.309 (0.448)	Recall 0.309 (0.448)
# Epoch:[1][1060/1224]	Loss 0.367 	Accuracy 0.574	Precison 0.574 (0.448)	Recall 0.574 (0.448)
# Epoch:[1][1065/1224]	Loss 0.338 	Accuracy 0.699	Precison 0.699 (0.449)	Recall 0.699 (0.449)
# Epoch:[1][1070/1224]	Loss 0.397 	Accuracy 0.348	Precison 0.348 (0.449)	Recall 0.348 (0.449)
# Epoch:[1][1075/1224]	Loss 0.480 	Accuracy 0.000	Precison 0.000 (0.448)	Recall 0.000 (0.448)
# Epoch:[1][1080/1224]	Loss 0.505 	Accuracy 0.000	Precison 0.000 (0.447)	Recall 0.000 (0.447)
# Epoch:[1][1085/1224]	Loss 0.336 	Accuracy 0.633	Precison 0.633 (0.447)	Recall 0.633 (0.447)
# Epoch:[1][1090/1224]	Loss 0.436 	Accuracy 0.172	Precison 0.172 (0.447)	Recall 0.172 (0.447)
# Epoch:[1][1095/1224]	Loss 0.249 	Accuracy 1.000	Precison 1.000 (0.447)	Recall 1.000 (0.447)
# Epoch:[1][1100/1224]	Loss 0.439 	Accuracy 0.355	Precison 0.355 (0.448)	Recall 0.355 (0.448)
# Epoch:[1][1105/1224]	Loss 0.487 	Accuracy 0.086	Precison 0.086 (0.448)	Recall 0.086 (0.448)
# Epoch:[1][1110/1224]	Loss 0.414 	Accuracy 0.137	Precison 0.137 (0.447)	Recall 0.137 (0.447)
# Epoch:[1][1115/1224]	Loss 0.409 	Accuracy 0.395	Precison 0.395 (0.447)	Recall 0.395 (0.447)
# Epoch:[1][1120/1224]	Loss 0.375 	Accuracy 0.477	Precison 0.477 (0.447)	Recall 0.477 (0.447)
# Epoch:[1][1125/1224]	Loss 0.492 	Accuracy 0.090	Precison 0.090 (0.447)	Recall 0.090 (0.447)
# Epoch:[1][1130/1224]	Loss 0.461 	Accuracy 0.152	Precison 0.152 (0.446)	Recall 0.152 (0.446)
# Epoch:[1][1135/1224]	Loss 0.417 	Accuracy 1.000	Precison 1.000 (0.446)	Recall 1.000 (0.446)
# Epoch:[1][1140/1224]	Loss 0.417 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[1][1145/1224]	Loss 0.391 	Accuracy 0.445	Precison 0.445 (0.448)	Recall 0.445 (0.448)
# Epoch:[1][1150/1224]	Loss 0.368 	Accuracy 0.500	Precison 0.500 (0.449)	Recall 0.500 (0.449)
# Epoch:[1][1155/1224]	Loss 0.449 	Accuracy 0.117	Precison 0.117 (0.448)	Recall 0.117 (0.448)
# Epoch:[1][1160/1224]	Loss 0.463 	Accuracy 0.344	Precison 0.344 (0.448)	Recall 0.344 (0.448)
# Epoch:[1][1165/1224]	Loss 0.300 	Accuracy 1.000	Precison 1.000 (0.449)	Recall 1.000 (0.449)
# Epoch:[1][1170/1224]	Loss 0.502 	Accuracy 0.000	Precison 0.000 (0.448)	Recall 0.000 (0.448)
# Epoch:[1][1175/1224]	Loss 0.284 	Accuracy 0.941	Precison 0.941 (0.448)	Recall 0.941 (0.448)
# Epoch:[1][1180/1224]	Loss 0.368 	Accuracy 0.652	Precison 0.652 (0.448)	Recall 0.652 (0.448)
# Epoch:[1][1185/1224]	Loss 0.400 	Accuracy 0.426	Precison 0.426 (0.448)	Recall 0.426 (0.448)
# Epoch:[1][1190/1224]	Loss 0.315 	Accuracy 0.676	Precison 0.676 (0.448)	Recall 0.676 (0.448)
# Epoch:[1][1195/1224]	Loss 0.474 	Accuracy 1.000	Precison 1.000 (0.448)	Recall 1.000 (0.448)
# Epoch:[1][1200/1224]	Loss 0.327 	Accuracy 1.000	Precison 1.000 (0.449)	Recall 1.000 (0.449)
# Epoch:[1][1205/1224]	Loss 0.495 	Accuracy 0.000	Precison 0.000 (0.449)	Recall 0.000 (0.449)
# Epoch:[1][1210/1224]	Loss 0.370 	Accuracy 0.574	Precison 0.574 (0.449)	Recall 0.574 (0.449)
# Epoch:[1][1215/1224]	Loss 0.463 	Accuracy 0.148	Precison 0.148 (0.449)	Recall 0.148 (0.449)
# Epoch:[1][1220/1224]	Loss 0.411 	Accuracy 0.262	Precison 0.262 (0.449)	Recall 0.262 (0.449)
# Epoch:[2][0/1224]	Loss 0.427 	Accuracy 0.395	Precison 0.395 (0.449)	Recall 0.395 (0.449)
# Epoch:[2][5/1224]	Loss 0.364 	Accuracy 0.531	Precison 0.531 (0.449)	Recall 0.531 (0.449)
# Epoch:[2][10/1224]	Loss 0.388 	Accuracy 0.613	Precison 0.613 (0.449)	Recall 0.613 (0.449)
# Epoch:[2][15/1224]	Loss 0.435 	Accuracy 0.281	Precison 0.281 (0.448)	Recall 0.281 (0.448)
# Epoch:[2][20/1224]	Loss 0.454 	Accuracy 0.316	Precison 0.316 (0.448)	Recall 0.316 (0.448)
# Epoch:[2][25/1224]	Loss 0.395 	Accuracy 0.707	Precison 0.707 (0.448)	Recall 0.707 (0.448)
# Epoch:[2][30/1224]	Loss 0.496 	Accuracy 0.000	Precison 0.000 (0.448)	Recall 0.000 (0.448)
# Epoch:[2][35/1224]	Loss 0.389 	Accuracy 0.781	Precison 0.781 (0.448)	Recall 0.781 (0.448)
# Epoch:[2][40/1224]	Loss 0.392 	Accuracy 0.547	Precison 0.547 (0.449)	Recall 0.547 (0.449)
# Epoch:[2][45/1224]	Loss 0.405 	Accuracy 0.398	Precison 0.398 (0.449)	Recall 0.398 (0.449)
# Epoch:[2][50/1224]	Loss 0.405 	Accuracy 0.344	Precison 0.344 (0.448)	Recall 0.344 (0.448)
# Epoch:[2][55/1224]	Loss 0.399 	Accuracy 0.465	Precison 0.465 (0.448)	Recall 0.465 (0.448)
# Epoch:[2][60/1224]	Loss 0.345 	Accuracy 0.645	Precison 0.645 (0.448)	Recall 0.645 (0.448)
# Epoch:[2][65/1224]	Loss 0.351 	Accuracy 0.965	Precison 0.965 (0.449)	Recall 0.965 (0.449)
# Epoch:[2][70/1224]	Loss 0.394 	Accuracy 0.391	Precison 0.391 (0.449)	Recall 0.391 (0.449)
# Epoch:[2][75/1224]	Loss 0.396 	Accuracy 0.344	Precison 0.344 (0.449)	Recall 0.344 (0.449)
# Epoch:[2][80/1224]	Loss 0.426 	Accuracy 0.336	Precison 0.336 (0.449)	Recall 0.336 (0.449)
# Epoch:[2][85/1224]	Loss 0.407 	Accuracy 0.324	Precison 0.324 (0.448)	Recall 0.324 (0.448)
# Epoch:[2][90/1224]	Loss 0.326 	Accuracy 0.645	Precison 0.645 (0.448)	Recall 0.645 (0.448)
# Epoch:[2][95/1224]	Loss 0.374 	Accuracy 0.355	Precison 0.355 (0.449)	Recall 0.355 (0.449)
# Epoch:[2][100/1224]	Loss 0.367 	Accuracy 0.973	Precison 0.973 (0.449)	Recall 0.973 (0.449)
# Epoch:[2][105/1224]	Loss 0.408 	Accuracy 0.379	Precison 0.379 (0.449)	Recall 0.379 (0.449)
# Epoch:[2][110/1224]	Loss 0.469 	Accuracy 0.238	Precison 0.238 (0.448)	Recall 0.238 (0.448)
# Epoch:[2][115/1224]	Loss 0.482 	Accuracy 1.000	Precison 1.000 (0.449)	Recall 1.000 (0.449)
# Epoch:[2][120/1224]	Loss 0.337 	Accuracy 0.695	Precison 0.695 (0.449)	Recall 0.695 (0.449)
# Epoch:[2][125/1224]	Loss 0.353 	Accuracy 0.609	Precison 0.609 (0.449)	Recall 0.609 (0.449)
# Epoch:[2][130/1224]	Loss 0.316 	Accuracy 0.738	Precison 0.738 (0.449)	Recall 0.738 (0.449)
# Epoch:[2][135/1224]	Loss 0.359 	Accuracy 0.500	Precison 0.500 (0.450)	Recall 0.500 (0.450)
# Epoch:[2][140/1224]	Loss 0.502 	Accuracy 0.000	Precison 0.000 (0.449)	Recall 0.000 (0.449)
# Epoch:[2][145/1224]	Loss 0.270 	Accuracy 0.973	Precison 0.973 (0.450)	Recall 0.973 (0.450)
# Epoch:[2][150/1224]	Loss 0.485 	Accuracy 0.086	Precison 0.086 (0.450)	Recall 0.086 (0.450)
# Epoch:[2][155/1224]	Loss 0.509 	Accuracy 0.000	Precison 0.000 (0.450)	Recall 0.000 (0.450)
# ...
# Epoch:[11][175/1224]	Loss 0.449 	Accuracy 0.000	Precison 0.000 (0.461)	Recall 0.000 (0.461)
# Epoch:[11][180/1224]	Loss 0.494 	Accuracy 0.000	Precison 0.000 (0.461)	Recall 0.000 (0.461)
# Epoch:[11][185/1224]	Loss 0.362 	Accuracy 0.594	Precison 0.594 (0.461)	Recall 0.594 (0.461)
# Epoch:[11][190/1224]	Loss 0.376 	Accuracy 0.078	Precison 0.078 (0.461)	Recall 0.078 (0.461)
# Epoch:[11][195/1224]	Loss 0.452 	Accuracy 0.168	Precison 0.168 (0.461)	Recall 0.168 (0.461)
# Epoch:[11][200/1224]	Loss 0.328 	Accuracy 0.633	Precison 0.633 (0.461)	Recall 0.633 (0.461)
# Epoch:[11][205/1224]	Loss 0.364 	Accuracy 0.852	Precison 0.852 (0.461)	Recall 0.852 (0.461)
# Epoch:[11][210/1224]	Loss 0.171 	Accuracy 1.000	Precison 1.000 (0.461)	Recall 1.000 (0.461)
# Epoch:[11][215/1224]	Loss 0.485 	Accuracy 0.000	Precison 0.000 (0.461)	Recall 0.000 (0.461)
# Epoch:[11][220/1224]	Loss 0.198 	Accuracy 1.000	Precison 1.000 (0.461)	Recall 1.000 (0.461)
# Epoch:[11][225/1224]	Loss 0.186 	Accuracy 0.969	Precison 0.969 (0.461)	Recall 0.969 (0.461)
# Epoch:[11][230/1224]	Loss 0.433 	Accuracy 0.520	Precison 0.520 (0.462)	Recall 0.520 (0.462)
# Epoch:[11][235/1224]	Loss 0.418 	Accuracy 0.312	Precison 0.312 (0.461)	Recall 0.312 (0.461)
# Epoch:[11][240/1224]	Loss 0.306 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][245/1224]	Loss 0.523 	Accuracy 0.852	Precison 0.852 (0.462)	Recall 0.852 (0.462)
# Epoch:[11][250/1224]	Loss 0.431 	Accuracy 0.160	Precison 0.160 (0.462)	Recall 0.160 (0.462)
# Epoch:[11][255/1224]	Loss 0.443 	Accuracy 0.203	Precison 0.203 (0.462)	Recall 0.203 (0.462)
# Epoch:[11][260/1224]	Loss 0.387 	Accuracy 0.434	Precison 0.434 (0.462)	Recall 0.434 (0.462)
# Epoch:[11][265/1224]	Loss 0.247 	Accuracy 0.758	Precison 0.758 (0.462)	Recall 0.758 (0.462)
# Epoch:[11][270/1224]	Loss 0.295 	Accuracy 0.703	Precison 0.703 (0.462)	Recall 0.703 (0.462)
# Epoch:[11][275/1224]	Loss 0.348 	Accuracy 0.555	Precison 0.555 (0.462)	Recall 0.555 (0.462)
# Epoch:[11][280/1224]	Loss 0.409 	Accuracy 0.469	Precison 0.469 (0.462)	Recall 0.469 (0.462)
# Epoch:[11][285/1224]	Loss 0.265 	Accuracy 0.680	Precison 0.680 (0.462)	Recall 0.680 (0.462)
# Epoch:[11][290/1224]	Loss 0.370 	Accuracy 0.426	Precison 0.426 (0.462)	Recall 0.426 (0.462)
# Epoch:[11][295/1224]	Loss 0.373 	Accuracy 0.492	Precison 0.492 (0.462)	Recall 0.492 (0.462)
# Epoch:[11][300/1224]	Loss 0.429 	Accuracy 0.375	Precison 0.375 (0.462)	Recall 0.375 (0.462)
# Epoch:[11][305/1224]	Loss 0.367 	Accuracy 0.816	Precison 0.816 (0.462)	Recall 0.816 (0.462)
# Epoch:[11][310/1224]	Loss 0.322 	Accuracy 0.969	Precison 0.969 (0.462)	Recall 0.969 (0.462)
# Epoch:[11][315/1224]	Loss 0.309 	Accuracy 0.809	Precison 0.809 (0.462)	Recall 0.809 (0.462)
# Epoch:[11][320/1224]	Loss 0.398 	Accuracy 0.422	Precison 0.422 (0.462)	Recall 0.422 (0.462)
# Epoch:[11][325/1224]	Loss 0.369 	Accuracy 0.414	Precison 0.414 (0.462)	Recall 0.414 (0.462)
# Epoch:[11][330/1224]	Loss 0.078 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][335/1224]	Loss 0.331 	Accuracy 0.566	Precison 0.566 (0.462)	Recall 0.566 (0.462)
# Epoch:[11][340/1224]	Loss 0.488 	Accuracy 0.070	Precison 0.070 (0.462)	Recall 0.070 (0.462)
# Epoch:[11][345/1224]	Loss 0.338 	Accuracy 0.492	Precison 0.492 (0.462)	Recall 0.492 (0.462)
# Epoch:[11][350/1224]	Loss 0.341 	Accuracy 0.605	Precison 0.605 (0.462)	Recall 0.605 (0.462)
# Epoch:[11][355/1224]	Loss 0.357 	Accuracy 0.559	Precison 0.559 (0.462)	Recall 0.559 (0.462)
# Epoch:[11][360/1224]	Loss 0.318 	Accuracy 0.938	Precison 0.938 (0.462)	Recall 0.938 (0.462)
# Epoch:[11][365/1224]	Loss 0.509 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][370/1224]	Loss 0.389 	Accuracy 0.426	Precison 0.426 (0.462)	Recall 0.426 (0.462)
# Epoch:[11][375/1224]	Loss 0.364 	Accuracy 0.473	Precison 0.473 (0.462)	Recall 0.473 (0.462)
# Epoch:[11][380/1224]	Loss 0.388 	Accuracy 0.414	Precison 0.414 (0.462)	Recall 0.414 (0.462)
# Epoch:[11][385/1224]	Loss 0.335 	Accuracy 0.621	Precison 0.621 (0.462)	Recall 0.621 (0.462)
# Epoch:[11][390/1224]	Loss 0.396 	Accuracy 0.461	Precison 0.461 (0.462)	Recall 0.461 (0.462)
# Epoch:[11][395/1224]	Loss 0.292 	Accuracy 0.512	Precison 0.512 (0.462)	Recall 0.512 (0.462)
# Epoch:[11][400/1224]	Loss 0.335 	Accuracy 0.508	Precison 0.508 (0.462)	Recall 0.508 (0.462)
# Epoch:[11][405/1224]	Loss 0.319 	Accuracy 0.688	Precison 0.688 (0.462)	Recall 0.688 (0.462)
# Epoch:[11][410/1224]	Loss 0.383 	Accuracy 0.336	Precison 0.336 (0.462)	Recall 0.336 (0.462)
# Epoch:[11][415/1224]	Loss 0.488 	Accuracy 0.316	Precison 0.316 (0.462)	Recall 0.316 (0.462)
# Epoch:[11][420/1224]	Loss 0.511 	Accuracy 0.078	Precison 0.078 (0.462)	Recall 0.078 (0.462)
# Epoch:[11][425/1224]	Loss 0.302 	Accuracy 0.766	Precison 0.766 (0.462)	Recall 0.766 (0.462)
# Epoch:[11][430/1224]	Loss 0.473 	Accuracy 0.188	Precison 0.188 (0.462)	Recall 0.188 (0.462)
# Epoch:[11][435/1224]	Loss 0.259 	Accuracy 0.801	Precison 0.801 (0.462)	Recall 0.801 (0.462)
# Epoch:[11][440/1224]	Loss 0.467 	Accuracy 0.305	Precison 0.305 (0.462)	Recall 0.305 (0.462)
# Epoch:[11][445/1224]	Loss 0.494 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][450/1224]	Loss 0.599 	Accuracy 0.105	Precison 0.105 (0.462)	Recall 0.105 (0.462)
# Epoch:[11][455/1224]	Loss 0.489 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][460/1224]	Loss 0.492 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][465/1224]	Loss 0.325 	Accuracy 0.602	Precison 0.602 (0.462)	Recall 0.602 (0.462)
# Epoch:[11][470/1224]	Loss 0.349 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][475/1224]	Loss 0.191 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][480/1224]	Loss 0.368 	Accuracy 0.602	Precison 0.602 (0.462)	Recall 0.602 (0.462)
# Epoch:[11][485/1224]	Loss 0.309 	Accuracy 0.977	Precison 0.977 (0.462)	Recall 0.977 (0.462)
# Epoch:[11][490/1224]	Loss 0.487 	Accuracy 0.020	Precison 0.020 (0.462)	Recall 0.020 (0.462)
# Epoch:[11][495/1224]	Loss 0.312 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][500/1224]	Loss 0.414 	Accuracy 0.996	Precison 0.996 (0.462)	Recall 0.996 (0.462)
# Epoch:[11][505/1224]	Loss 0.249 	Accuracy 0.938	Precison 0.938 (0.462)	Recall 0.938 (0.462)
# Epoch:[11][510/1224]	Loss 0.402 	Accuracy 0.312	Precison 0.312 (0.462)	Recall 0.312 (0.462)
# Epoch:[11][515/1224]	Loss 0.501 	Accuracy 0.160	Precison 0.160 (0.462)	Recall 0.160 (0.462)
# Epoch:[11][520/1224]	Loss 0.260 	Accuracy 0.773	Precison 0.773 (0.462)	Recall 0.773 (0.462)
# Epoch:[11][525/1224]	Loss 0.408 	Accuracy 0.430	Precison 0.430 (0.462)	Recall 0.430 (0.462)
# Epoch:[11][530/1224]	Loss 0.492 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][535/1224]	Loss 0.492 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][540/1224]	Loss 0.377 	Accuracy 0.379	Precison 0.379 (0.462)	Recall 0.379 (0.462)
# Epoch:[11][545/1224]	Loss 0.347 	Accuracy 0.629	Precison 0.629 (0.462)	Recall 0.629 (0.462)
# Epoch:[11][550/1224]	Loss 0.485 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][555/1224]	Loss 0.465 	Accuracy 0.070	Precison 0.070 (0.462)	Recall 0.070 (0.462)
# Epoch:[11][560/1224]	Loss 0.451 	Accuracy 0.125	Precison 0.125 (0.462)	Recall 0.125 (0.462)
# Epoch:[11][565/1224]	Loss 0.484 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][570/1224]	Loss 0.481 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][575/1224]	Loss 0.269 	Accuracy 0.848	Precison 0.848 (0.462)	Recall 0.848 (0.462)
# Epoch:[11][580/1224]	Loss 0.346 	Accuracy 0.488	Precison 0.488 (0.462)	Recall 0.488 (0.462)
# Epoch:[11][585/1224]	Loss 0.218 	Accuracy 0.785	Precison 0.785 (0.462)	Recall 0.785 (0.462)
# Epoch:[11][590/1224]	Loss 0.423 	Accuracy 0.238	Precison 0.238 (0.462)	Recall 0.238 (0.462)
# Epoch:[11][595/1224]	Loss 0.364 	Accuracy 0.492	Precison 0.492 (0.462)	Recall 0.492 (0.462)
# Epoch:[11][600/1224]	Loss 0.348 	Accuracy 0.438	Precison 0.438 (0.462)	Recall 0.438 (0.462)
# Epoch:[11][605/1224]	Loss 0.391 	Accuracy 0.379	Precison 0.379 (0.462)	Recall 0.379 (0.462)
# Epoch:[11][610/1224]	Loss 0.388 	Accuracy 0.645	Precison 0.645 (0.462)	Recall 0.645 (0.462)
# Epoch:[11][615/1224]	Loss 0.478 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][620/1224]	Loss 0.273 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][625/1224]	Loss 0.477 	Accuracy 0.000	Precison 0.000 (0.462)	Recall 0.000 (0.462)
# Epoch:[11][630/1224]	Loss 0.372 	Accuracy 0.410	Precison 0.410 (0.462)	Recall 0.410 (0.462)
# Epoch:[11][635/1224]	Loss 0.303 	Accuracy 0.910	Precison 0.910 (0.462)	Recall 0.910 (0.462)
# Epoch:[11][640/1224]	Loss 0.376 	Accuracy 0.430	Precison 0.430 (0.462)	Recall 0.430 (0.462)
# Epoch:[11][645/1224]	Loss 0.369 	Accuracy 0.500	Precison 0.500 (0.462)	Recall 0.500 (0.462)
# Epoch:[11][650/1224]	Loss 0.311 	Accuracy 0.602	Precison 0.602 (0.462)	Recall 0.602 (0.462)
# Epoch:[11][655/1224]	Loss 0.451 	Accuracy 0.199	Precison 0.199 (0.462)	Recall 0.199 (0.462)
# Epoch:[11][660/1224]	Loss 0.081 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][665/1224]	Loss 0.077 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][670/1224]	Loss 0.451 	Accuracy 0.172	Precison 0.172 (0.462)	Recall 0.172 (0.462)
# Epoch:[11][675/1224]	Loss 0.292 	Accuracy 0.742	Precison 0.742 (0.462)	Recall 0.742 (0.462)
# Epoch:[11][680/1224]	Loss 0.435 	Accuracy 0.977	Precison 0.977 (0.463)	Recall 0.977 (0.463)
# Epoch:[11][685/1224]	Loss 0.484 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][690/1224]	Loss 0.454 	Accuracy 0.949	Precison 0.949 (0.463)	Recall 0.949 (0.463)
# Epoch:[11][695/1224]	Loss 0.348 	Accuracy 0.613	Precison 0.613 (0.463)	Recall 0.613 (0.463)
# Epoch:[11][700/1224]	Loss 0.407 	Accuracy 0.590	Precison 0.590 (0.463)	Recall 0.590 (0.463)
# Epoch:[11][705/1224]	Loss 0.358 	Accuracy 0.535	Precison 0.535 (0.463)	Recall 0.535 (0.463)
# Epoch:[11][710/1224]	Loss 0.435 	Accuracy 0.199	Precison 0.199 (0.463)	Recall 0.199 (0.463)
# Epoch:[11][715/1224]	Loss 0.479 	Accuracy 0.223	Precison 0.223 (0.463)	Recall 0.223 (0.463)
# Epoch:[11][720/1224]	Loss 0.486 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][725/1224]	Loss 0.396 	Accuracy 0.434	Precison 0.434 (0.463)	Recall 0.434 (0.463)
# Epoch:[11][730/1224]	Loss 0.061 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][735/1224]	Loss 0.463 	Accuracy 0.066	Precison 0.066 (0.463)	Recall 0.066 (0.463)
# Epoch:[11][740/1224]	Loss 0.401 	Accuracy 0.418	Precison 0.418 (0.463)	Recall 0.418 (0.463)
# Epoch:[11][745/1224]	Loss 0.432 	Accuracy 0.203	Precison 0.203 (0.463)	Recall 0.203 (0.463)
# Epoch:[11][750/1224]	Loss 0.389 	Accuracy 0.422	Precison 0.422 (0.462)	Recall 0.422 (0.462)
# Epoch:[11][755/1224]	Loss 0.472 	Accuracy 0.023	Precison 0.023 (0.462)	Recall 0.023 (0.462)
# Epoch:[11][760/1224]	Loss 0.380 	Accuracy 0.520	Precison 0.520 (0.462)	Recall 0.520 (0.462)
# Epoch:[11][765/1224]	Loss 0.062 	Accuracy 1.000	Precison 1.000 (0.462)	Recall 1.000 (0.462)
# Epoch:[11][770/1224]	Loss 0.081 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][775/1224]	Loss 0.411 	Accuracy 0.562	Precison 0.562 (0.463)	Recall 0.562 (0.463)
# Epoch:[11][780/1224]	Loss 0.226 	Accuracy 0.938	Precison 0.938 (0.463)	Recall 0.938 (0.463)
# Epoch:[11][785/1224]	Loss 0.370 	Accuracy 0.652	Precison 0.652 (0.463)	Recall 0.652 (0.463)
# Epoch:[11][790/1224]	Loss 0.414 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][795/1224]	Loss 0.421 	Accuracy 0.328	Precison 0.328 (0.463)	Recall 0.328 (0.463)
# Epoch:[11][800/1224]	Loss 0.512 	Accuracy 0.148	Precison 0.148 (0.463)	Recall 0.148 (0.463)
# Epoch:[11][805/1224]	Loss 0.320 	Accuracy 0.914	Precison 0.914 (0.463)	Recall 0.914 (0.463)
# Epoch:[11][810/1224]	Loss 0.542 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][815/1224]	Loss 0.423 	Accuracy 0.262	Precison 0.262 (0.463)	Recall 0.262 (0.463)
# Epoch:[11][820/1224]	Loss 0.307 	Accuracy 0.645	Precison 0.645 (0.463)	Recall 0.645 (0.463)
# Epoch:[11][825/1224]	Loss 0.483 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][830/1224]	Loss 0.379 	Accuracy 0.422	Precison 0.422 (0.463)	Recall 0.422 (0.463)
# Epoch:[11][835/1224]	Loss 0.430 	Accuracy 0.234	Precison 0.234 (0.463)	Recall 0.234 (0.463)
# Epoch:[11][840/1224]	Loss 0.299 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][845/1224]	Loss 0.414 	Accuracy 0.336	Precison 0.336 (0.463)	Recall 0.336 (0.463)
# Epoch:[11][850/1224]	Loss 0.469 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][855/1224]	Loss 0.473 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][860/1224]	Loss 0.358 	Accuracy 0.555	Precison 0.555 (0.462)	Recall 0.555 (0.462)
# Epoch:[11][865/1224]	Loss 0.409 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][870/1224]	Loss 0.202 	Accuracy 0.973	Precison 0.973 (0.463)	Recall 0.973 (0.463)
# Epoch:[11][875/1224]	Loss 0.238 	Accuracy 0.863	Precison 0.863 (0.463)	Recall 0.863 (0.463)
# Epoch:[11][880/1224]	Loss 0.309 	Accuracy 0.758	Precison 0.758 (0.463)	Recall 0.758 (0.463)
# Epoch:[11][885/1224]	Loss 0.376 	Accuracy 0.418	Precison 0.418 (0.463)	Recall 0.418 (0.463)
# Epoch:[11][890/1224]	Loss 0.382 	Accuracy 0.398	Precison 0.398 (0.463)	Recall 0.398 (0.463)
# Epoch:[11][895/1224]	Loss 0.397 	Accuracy 0.363	Precison 0.363 (0.463)	Recall 0.363 (0.463)
# Epoch:[11][900/1224]	Loss 0.439 	Accuracy 0.043	Precison 0.043 (0.463)	Recall 0.043 (0.463)
# Epoch:[11][905/1224]	Loss 0.382 	Accuracy 0.406	Precison 0.406 (0.463)	Recall 0.406 (0.463)
# Epoch:[11][910/1224]	Loss 0.429 	Accuracy 0.910	Precison 0.910 (0.463)	Recall 0.910 (0.463)
# Epoch:[11][915/1224]	Loss 0.458 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][920/1224]	Loss 0.371 	Accuracy 0.449	Precison 0.449 (0.463)	Recall 0.449 (0.463)
# Epoch:[11][925/1224]	Loss 0.423 	Accuracy 0.270	Precison 0.270 (0.463)	Recall 0.270 (0.463)
# Epoch:[11][930/1224]	Loss 0.418 	Accuracy 0.277	Precison 0.277 (0.463)	Recall 0.277 (0.463)
# Epoch:[11][935/1224]	Loss 0.478 	Accuracy 0.059	Precison 0.059 (0.463)	Recall 0.059 (0.463)
# Epoch:[11][940/1224]	Loss 0.417 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][945/1224]	Loss 0.303 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][950/1224]	Loss 0.504 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][955/1224]	Loss 0.336 	Accuracy 0.750	Precison 0.750 (0.463)	Recall 0.750 (0.463)
# Epoch:[11][960/1224]	Loss 0.237 	Accuracy 0.859	Precison 0.859 (0.463)	Recall 0.859 (0.463)
# Epoch:[11][965/1224]	Loss 0.480 	Accuracy 0.230	Precison 0.230 (0.463)	Recall 0.230 (0.463)
# Epoch:[11][970/1224]	Loss 0.327 	Accuracy 0.609	Precison 0.609 (0.463)	Recall 0.609 (0.463)
# Epoch:[11][975/1224]	Loss 0.233 	Accuracy 0.914	Precison 0.914 (0.463)	Recall 0.914 (0.463)
# Epoch:[11][980/1224]	Loss 0.266 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][985/1224]	Loss 0.260 	Accuracy 0.688	Precison 0.688 (0.463)	Recall 0.688 (0.463)
# Epoch:[11][990/1224]	Loss 0.424 	Accuracy 0.289	Precison 0.289 (0.463)	Recall 0.289 (0.463)
# Epoch:[11][995/1224]	Loss 0.317 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][1000/1224]	Loss 0.288 	Accuracy 0.727	Precison 0.727 (0.463)	Recall 0.727 (0.463)
# Epoch:[11][1005/1224]	Loss 0.414 	Accuracy 0.062	Precison 0.062 (0.463)	Recall 0.062 (0.463)
# Epoch:[11][1010/1224]	Loss 0.494 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][1015/1224]	Loss 0.071 	Accuracy 1.000	Precison 1.000 (0.463)	Recall 1.000 (0.463)
# Epoch:[11][1020/1224]	Loss 0.382 	Accuracy 0.414	Precison 0.414 (0.463)	Recall 0.414 (0.463)
# Epoch:[11][1025/1224]	Loss 0.355 	Accuracy 0.598	Precison 0.598 (0.463)	Recall 0.598 (0.463)
# Epoch:[11][1030/1224]	Loss 0.486 	Accuracy 0.000	Precison 0.000 (0.463)	Recall 0.000 (0.463)
# Epoch:[11][1035/1224]	Loss 0.361 	Accuracy 0.473	Precison 0.473 (0.463)	Recall 0.473 (0.463)

# %%
len(dataloader)
# Out:
# 1224

# %%
model = RNN(516,290,512)

# %%
model.forward(data)
# Out:
# torch.LongTensor
# tensor([[-0.0257, -0.0630, -0.0623,  0.1361, -0.0200, -0.0039,  0.0120,  0.0412,
#          -0.0994,  0.0217, -0.0275,  0.1178,  0.0206, -0.0918, -0.0219, -0.0159,
#          -0.0219, -0.0197, -0.1264, -0.1075,  0.1100,  0.0266, -0.0780, -0.1267,
#          -0.0762, -0.0070, -0.0137,  0.0014, -0.1870, -0.0176, -0.0502, -0.0260,
#           0.0059,  0.0530, -0.0432,  0.0633, -0.0933,  0.0084,  0.0375,  0.0401,
#          -0.0171, -0.0616, -0.0005, -0.0459,  0.0608,  0.0465,  0.0005,  0.0145,
#           0.0418, -0.1062, -0.0940,  0.0567,  0.0578,  0.0201,  0.0536,  0.1370,
#          -0.0172,  0.0106,  0.0296,  0.0684,  0.0232,  0.0435, -0.0316,  0.0069,
#          -0.0825, -0.1120, -0.0722,  0.0145, -0.0406, -0.0420,  0.0326,  0.0100,
#           0.0343, -0.0009, -0.0210,  0.0863,  0.0389, -0.0674, -0.1065,  0.0212,
#           0.0376,  0.0009,  0.0232,  0.0349,  0.0272,  0.0144,  0.0772, -0.0026,
#           0.1036, -0.0863, -0.0276, -0.0064,  0.0217, -0.0501, -0.0400, -0.0052,
#           0.1436, -0.0073, -0.0395, -0.1058,  0.0286, -0.0645, -0.0401, -0.0181,
#          -0.0282,  0.0215, -0.0855, -0.0523, -0.0070, -0.0209,  0.0538, -0.0599,
#          -0.0299, -0.0943, -0.0322, -0.0391, -0.0227, -0.0212, -0.0105, -0.0294,
#          -0.0307,  0.0720,  0.0859, -0.0941,  0.0243, -0.0720, -0.0919,  0.0378,
#           0.0431, -0.0071, -0.0816, -0.0726, -0.0535, -0.0178,  0.0490, -0.0093,
#           0.0107,  0.0743, -0.0206,  0.0324,  0.0890, -0.0929, -0.0446, -0.0726,
#          -0.0299,  0.0288,  0.0291,  0.0364,  0.0229,  0.0918,  0.0618,  0.0057,
#           0.0116,  0.0271, -0.0695,  0.1265,  0.0241,  0.0361, -0.0118, -0.0641,
#          -0.0659,  0.0697,  0.0787, -0.0241,  0.0055,  0.0151,  0.0233, -0.0166,
#           0.0314,  0.0935,  0.0223, -0.0479, -0.0080,  0.0641,  0.0142, -0.0227,
#          -0.0673, -0.0250,  0.0405,  0.0193, -0.0286,  0.1160, -0.0024,  0.0298,
#          -0.0907,  0.0479, -0.0201, -0.0582,  0.0504, -0.0143,  0.0505, -0.0282,
#           0.0256,  0.0155, -0.0403,  0.0508,  0.0128,  0.0386, -0.0028, -0.1184,
#          -0.0017, -0.0382, -0.0580,  0.0340,  0.0373, -0.0253,  0.0374,  0.0015,
#          -0.0044, -0.0229,  0.0780,  0.0720, -0.0613, -0.0286,  0.0232,  0.0180,
#          -0.0806, -0.0299, -0.0696, -0.0073, -0.0914, -0.0971, -0.0154, -0.0412,
#           0.1441, -0.0291,  0.1179,  0.0014, -0.1002,  0.1377,  0.0687, -0.0835,
#           0.0401, -0.0081, -0.0664,  0.0175,  0.0046, -0.0088,  0.0637,  0.0115,
#          -0.0347,  0.0020, -0.0522, -0.0441, -0.0672, -0.0153, -0.0835,  0.0114,
#           0.0254,  0.0780,  0.0184,  0.0463,  0.0205, -0.0648, -0.0088,  0.0561,
#           0.0586, -0.0373,  0.0686, -0.0151,  0.0299, -0.0166, -0.0408, -0.1667,
#          -0.0922, -0.0630, -0.0484,  0.0440, -0.0451, -0.0361, -0.0359,  0.0087,
#          -0.0129, -0.0619,  0.0463,  0.0446, -0.0453,  0.0933,  0.0294,  0.0571,
#          -0.0314, -0.0852, -0.0259, -0.0247, -0.0217, -0.0901, -0.0829, -0.0590,
#           0.0274,  0.0097],
#         [-0.0394, -0.0748, -0.0517,  0.1268, -0.0077, -0.0115,  0.0102,  0.0396,
#          -0.0880,  0.0157, -0.0180,  0.1219,  0.0133, -0.0854, -0.0253, -0.0172,
#          -0.0060, -0.0280, -0.1280, -0.1040,  0.1094,  0.0372, -0.0821, -0.1232,
#          -0.0765, -0.0083, -0.0147,  0.0017, -0.1711, -0.0213, -0.0585, -0.0237,
#           0.0110,  0.0529, -0.0482,  0.0557, -0.0741,  0.0043,  0.0281,  0.0324,
#          -0.0110, -0.0694,  0.0013, -0.0526,  0.0509,  0.0379,  0.0020,  0.0060,
#           0.0495, -0.1068, -0.0980,  0.0677,  0.0662,  0.0061,  0.0469,  0.1428,
#          -0.0258,  0.0059,  0.0312,  0.0625,  0.0366,  0.0441, -0.0203,  0.0117,
#          -0.0801, -0.0976, -0.0584,  0.0193, -0.0301, -0.0351,  0.0359, -0.0021,
#           0.0281, -0.0024, -0.0172,  0.0855,  0.0313, -0.0424, -0.1027,  0.0205,
#           0.0523,  0.0044,  0.0034,  0.0343,  0.0254,  0.0048,  0.0697, -0.0122,
#           0.1022, -0.0849, -0.0105, -0.0058,  0.0217, -0.0553, -0.0310, -0.0024,
#           0.1448, -0.0058, -0.0300, -0.1022,  0.0241, -0.0681, -0.0366, -0.0207,
#          -0.0407,  0.0223, -0.0918, -0.0492, -0.0134, -0.0130,  0.0634, -0.0513,
#          -0.0294, -0.0832, -0.0336, -0.0317, -0.0196, -0.0184, -0.0021, -0.0421,
#          -0.0260,  0.0725,  0.0845, -0.1054,  0.0305, -0.0590, -0.0984,  0.0368,
#           0.0495, -0.0109, -0.0816, -0.0627, -0.0575, -0.0243,  0.0535, -0.0078,
#           0.0265,  0.0766, -0.0167,  0.0437,  0.0919, -0.0902, -0.0559, -0.0677,
#          -0.0410,  0.0299,  0.0317,  0.0464,  0.0187,  0.0877,  0.0597,  0.0223,
#           0.0232,  0.0154, -0.0752,  0.1392,  0.0316,  0.0444,  0.0023, -0.0502,
#          -0.0798,  0.0710,  0.0757, -0.0356,  0.0157,  0.0147,  0.0134, -0.0150,
#           0.0272,  0.0968,  0.0040, -0.0579, -0.0163,  0.0549,  0.0193, -0.0183,
#          -0.0603, -0.0225,  0.0442,  0.0216, -0.0476,  0.1160,  0.0022,  0.0216,
#          -0.0859,  0.0533, -0.0109, -0.0410,  0.0583, -0.0158,  0.0533, -0.0312,
#           0.0193,  0.0236, -0.0335,  0.0603,  0.0078,  0.0388, -0.0049, -0.1268,
#          -0.0136, -0.0473, -0.0560,  0.0218,  0.0297, -0.0327,  0.0317,  0.0112,
#          -0.0087, -0.0075,  0.0834,  0.0636, -0.0602, -0.0317,  0.0304,  0.0148,
#          -0.0730, -0.0237, -0.0798, -0.0060, -0.0897, -0.1010, -0.0013, -0.0398,
#           0.1538, -0.0376,  0.1111,  0.0108, -0.0982,  0.1522,  0.0754, -0.0683,
#           0.0295, -0.0114, -0.0737,  0.0166,  0.0017,  0.0028,  0.0526,  0.0318,
#          -0.0228, -0.0042, -0.0483, -0.0503, -0.0678, -0.0073, -0.0850,  0.0188,
#           0.0257,  0.0995,  0.0286,  0.0341,  0.0350, -0.0592, -0.0199,  0.0437,
#           0.0614, -0.0334,  0.0752, -0.0260,  0.0340, -0.0370, -0.0379, -0.1753,
#          -0.0812, -0.0712, -0.0397,  0.0604, -0.0348, -0.0422, -0.0409,  0.0049,
#          -0.0255, -0.0601,  0.0497,  0.0326, -0.0470,  0.0836,  0.0402,  0.0564,
#          -0.0322, -0.0848, -0.0279, -0.0152, -0.0380, -0.0751, -0.0933, -0.0793,
#           0.0374,  0.0164]], grad_fn=<SliceBackward>)

# %%
batch_size = 1
seq_len = 3

inp = torch.randn(batch_size, seq_len, 10).to(torch.device('cuda:0'))
h = a.init_hidden(batch_size)
h = tuple([e.data for e in h])

# %%
out,h = a.forward(inp,h)
# Out:
# torch.Size([1, 3, 10])
# torch.Size([1, 3, 1024])
# torch.Size([1, 3, 512])

# %%
out.shape
# Out:
# torch.Size([1, 60])

# %%
out.shape
# Out:
# torch.Size([1, 60])

# %%
import torch
import torch.nn as nn
import numpy as np

EPOCHS = 500
IN_SIZE = 5
NUM_SAMPLES = 5

def generate_data(rows, columns, samples):
    X = []
    y = []
    transformations = {
        '11': lambda x, y: x + y,
        '15': lambda x, y: x - y,
        '10': lambda x, y: x * y,
        '30': lambda x, y: x / y,
        '2': lambda x, y: x + y,
        }
    for j in range(samples):
        data_set = []
        for i in range(columns):
            data = []
            for val, fn in transformations.items():
                data.append(int(fn(int(val), i+j+1)))
            data_set.append(data)
        X.append(data_set)
        y.append([j+1])
    return X, y


class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()

        self.rnn = nn.LSTM(
            input_size=5,
            hidden_size=NUM_SAMPLES+1,
            num_layers=2,
            batch_first=True,
    )

    def forward(self, x):
        out, (h_n, h_c) = self.rnn(x, None)
        return out[:, -1, :]	# Return output at last time-step


X, y = generate_data(IN_SIZE, 5, NUM_SAMPLES)
X = torch.FloatTensor(X)
y = torch.LongTensor(y)

rnn = RNN()
optimizer = torch.optim.Adam(rnn.parameters(), lr=0.001)
loss_func = nn.CrossEntropyLoss()

# %%
item
# Out:
# tensor([[[14., 12., 30., 10.,  5.],
#          [15., 11., 40.,  7.,  6.],
#          [16., 10., 50.,  6.,  7.],
#          [17.,  9., 60.,  5.,  8.],
#          [18.,  8., 70.,  4.,  9.]]])

# %%
output
# Out:
# tensor([[-0.9949, -0.9869,  0.9963, -0.9894, -0.9928, -0.9960]],
#        grad_fn=<SliceBackward>)

# %%
for j in range(EPOCHS):
    for i, item in enumerate(X):
        item.shape
        item = item.unsqueeze(0)
        output = rnn(item)
        loss = loss_func(output, y[i])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if j % 5 == 0:
        print('Loss: ', np.average(loss.detach()))
# Out:
# Loss:  0.67127174
# Loss:  0.6707352
# Loss:  0.67021835
# Loss:  0.6697202
# Loss:  0.66923946
# Loss:  0.6687752
# Loss:  0.6683264
# Loss:  0.6678922
# Loss:  0.66747177
# Loss:  0.6670644
# Loss:  0.66666967
# Loss:  0.6662865
# Loss:  0.66591483
# Loss:  0.66555375
# Loss:  0.665203
# Loss:  0.664862
# Loss:  0.6645304
# Loss:  0.66420776
# Loss:  0.6638938
# Loss:  0.66358805
# Loss:  0.6632902
# Loss:  0.663
# Loss:  0.6627171
# Loss:  0.66244125
# Loss:  0.66217214
# Loss:  0.66190964
# Loss:  0.6616534
# Loss:  0.6614034
# Loss:  0.6611591
# Loss:  0.66092044
# Loss:  0.6606872
# Loss:  0.6604594
# Loss:  0.6602366
# Loss:  0.6600187
# Loss:  0.6598054
# Loss:  0.6595967
# Loss:  0.65939224
# Loss:  0.65919185
# Loss:  0.6589953
# Loss:  0.65880215
# Loss:  0.6586126
# Loss:  0.65842706
# Loss:  0.6582459
# Loss:  0.65806925
# Loss:  0.6578964
# Loss:  0.657727
# Loss:  0.65756106
# Loss:  0.6573982
# Loss:  0.6572387
# Loss:  0.6570824
# Loss:  0.656929
# Loss:  0.6567785
# Loss:  0.65663105
# Loss:  0.6564863
# Loss:  0.6563443
# Loss:  0.65620494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-a5d45941bbf9> in <module>
#       3         item.shape
#       4         item = item.unsqueeze(0)
# ----> 5         output = rnn(item)
#       6         loss = loss_func(output, y[i])
#       7         optimizer.zero_grad()
#
# ~/myenv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-139-7470d444dd3c> in forward(self, x)
#      41
#      42     def forward(self, x):
# ---> 43         out, (h_n, h_c) = self.rnn(x, None)
#      44         return out[:, -1, :]    # Return output at last time-step
#      45
#
# ~/myenv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/myenv/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     580         if batch_sizes is None:
#     581             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 582                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     583         else:
#     584             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:
